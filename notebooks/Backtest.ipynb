# %%
"""
BTC Backtesting Script with Historical Data Collection
Collects BTC historical data from Alpaca, stores in TimescaleDB, and runs backtests
"""

import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import pytz
import logging
import sys
import os
from typing import Optional, Dict, Any
import warnings

# Suppress pandas SettingWithCopyWarning - we handle copying explicitly
pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# Modern Alpaca imports
from alpaca.trading.client import TradingClient
from alpaca.data.historical.crypto import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit

# Observability imports
from prometheus_client import Counter, Gauge, start_http_server, REGISTRY
import json
import requests

# Loki logging
from pythonjsonlogger import jsonlogger

# Database (TimescaleDB)
import psycopg2
from psycopg2.pool import SimpleConnectionPool

# MLflow
import mlflow

# Configure logging
class LokiHandler(logging.Handler):
    """Custom handler to send logs to Loki"""
    def __init__(self, loki_url, labels=None):
        super().__init__()
        self.loki_url = loki_url
        self.labels = labels or {}
        self.session = requests.Session()
        
    def emit(self, record):
        try:
            log_entry = {
                "streams": [{
                    "stream": {
                        "job": "btc_backtest",
                        "level": record.levelname.lower(),
                        **self.labels
                    },
                    "values": [[
                        str(int(record.created * 1e9)),
                        json.dumps({
                            "message": self.format(record),
                            "level": record.levelname,
                            "logger": record.name
                        })
                    ]]
                }]
            }
            response = self.session.post(self.loki_url, json=log_entry, timeout=5)
            response.raise_for_status()
        except Exception:
            pass

def setup_logging(level=logging.INFO, loki_url=None, loki_labels=None):
    """Setup logging"""
    logger = logging.getLogger()
    logger.setLevel(level)
    logger.handlers.clear()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    
    stream_handler = logging.StreamHandler(sys.stdout)
    stream_handler.setFormatter(formatter)
    logger.addHandler(stream_handler)
    
    if loki_url:
        try:
            loki_handler = LokiHandler(loki_url, loki_labels)
            loki_handler.setFormatter(formatter)
            logger.addHandler(loki_handler)
        except Exception:
            pass
    
    return logger

logger = setup_logging()

# Database connection pool for TimescaleDB
class TimescaleDB:
    """TimescaleDB connection and operations"""
    def __init__(self, connection_string=None):
        self.connection_string = connection_string
        self.pool = None
        if connection_string:
            try:
                self.pool = SimpleConnectionPool(1, 10, connection_string)
                self._init_schema()
                logger.info("TimescaleDB connection pool created")
            except Exception as e:
                logger.error(f"Failed to connect to TimescaleDB: {e}")
    
    def _init_schema(self):
        """Initialize database schema"""
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            
            # Create trades table
            cur.execute("""
                CREATE TABLE IF NOT EXISTS trades (
                    id SERIAL PRIMARY KEY,
                    timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                    symbol VARCHAR(50) NOT NULL,
                    direction VARCHAR(10) NOT NULL,
                    quantity DECIMAL(18, 8) NOT NULL,
                    entry_price DECIMAL(18, 2) NOT NULL,
                    stop_loss DECIMAL(18, 2),
                    take_profit DECIMAL(18, 2),
                    atr_value DECIMAL(18, 2),
                    status VARCHAR(20) DEFAULT 'open',
                    exit_price DECIMAL(18, 2),
                    exit_timestamp TIMESTAMPTZ,
                    pnl DECIMAL(18, 2),
                    daily_trade_number INTEGER,
                    mlflow_run_id VARCHAR(255)
                );
            """)
            
            # Create backtest_results table for storing metrics
            cur.execute("""
                CREATE TABLE IF NOT EXISTS backtest_results (
                    id SERIAL PRIMARY KEY,
                    timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                    start_date DATE NOT NULL,
                    end_date DATE NOT NULL,
                    symbol VARCHAR(50) NOT NULL,
                    timeframe VARCHAR(10) NOT NULL,
                    total_trades INTEGER,
                    winning_trades INTEGER,
                    losing_trades INTEGER,
                    win_rate DECIMAL(5, 4),
                    total_return_pct DECIMAL(10, 4),
                    roi DECIMAL(10, 4),
                    sharpe_ratio DECIMAL(10, 4),
                    max_drawdown_pct DECIMAL(10, 4),
                    profit_factor DECIMAL(10, 4),
                    avg_win_pct DECIMAL(10, 4),
                    avg_loss_pct DECIMAL(10, 4),
                    initial_capital DECIMAL(18, 2),
                    final_equity DECIMAL(18, 2),
                    net_profit DECIMAL(18, 2),
                    mlflow_run_id VARCHAR(255)
                );
            """)
            
            try:
                cur.execute("SELECT create_hypertable('trades', 'timestamp', if_not_exists => TRUE);")
                cur.execute("SELECT create_hypertable('backtest_results', 'timestamp', if_not_exists => TRUE);")
            except Exception:
                logger.warning("Could not create hypertable (may be regular PostgreSQL)")
            
            # Create index for backtest_results
            cur.execute("""
                CREATE INDEX IF NOT EXISTS idx_backtest_results_symbol_date 
                ON backtest_results (symbol, start_date, end_date);
            """)
            
            conn.commit()
            
            # Verify tables were created
            cur.execute("""
                SELECT table_name 
                FROM information_schema.tables 
                WHERE table_schema = 'public' 
                AND table_name IN ('trades', 'backtest_results');
            """)
            created_tables = [row[0] for row in cur.fetchall()]
            
            if 'trades' not in created_tables:
                logger.error("⚠️  WARNING: 'trades' table was not created!")
            if 'backtest_results' not in created_tables:
                logger.error("⚠️  WARNING: 'backtest_results' table was not created!")
            
            logger.info(f"TimescaleDB schema initialized. Tables: {created_tables}")
        except Exception as e:
            conn.rollback()
            logger.error(f"❌ Schema initialization error: {e}", exc_info=True)
            # Try to create tables individually with better error handling
            try:
                cur2 = conn.cursor()
                cur2.execute("""
                    CREATE TABLE IF NOT EXISTS trades (
                        id SERIAL PRIMARY KEY,
                        timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                        symbol VARCHAR(50) NOT NULL,
                        direction VARCHAR(10) NOT NULL,
                        quantity DECIMAL(18, 8) NOT NULL,
                        entry_price DECIMAL(18, 2) NOT NULL,
                        stop_loss DECIMAL(18, 2),
                        take_profit DECIMAL(18, 2),
                        atr_value DECIMAL(18, 2),
                        status VARCHAR(20) DEFAULT 'open',
                        exit_price DECIMAL(18, 2),
                        exit_timestamp TIMESTAMPTZ,
                        pnl DECIMAL(18, 2),
                        daily_trade_number INTEGER,
                        mlflow_run_id VARCHAR(255)
                    );
                """)
                conn.commit()
                cur2.close()
                logger.info("✓ Trades table created successfully (fallback)")
            except Exception as e2:
                logger.error(f"Failed to create trades table (fallback): {e2}", exc_info=True)
        finally:
            self.pool.putconn(conn)
    
    def insert_backtest_results(self, metrics_data):
        """Insert backtest metrics into database"""
        if not self.pool:
            return None
        
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            cur.execute("""
                INSERT INTO backtest_results (
                    start_date, end_date, symbol, timeframe,
                    total_trades, winning_trades, losing_trades, win_rate,
                    total_return_pct, roi, sharpe_ratio, max_drawdown_pct,
                    profit_factor, avg_win_pct, avg_loss_pct,
                    initial_capital, final_equity, net_profit, mlflow_run_id
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                RETURNING id;
            """, (
                metrics_data.get('start_date'),
                metrics_data.get('end_date'),
                metrics_data.get('symbol'),
                metrics_data.get('timeframe'),
                metrics_data.get('total_trades'),
                metrics_data.get('winning_trades'),
                metrics_data.get('losing_trades'),
                metrics_data.get('win_rate'),
                metrics_data.get('total_return_pct'),
                metrics_data.get('roi'),
                metrics_data.get('sharpe_ratio'),
                metrics_data.get('max_drawdown_pct'),
                metrics_data.get('profit_factor'),
                metrics_data.get('avg_win_pct'),
                metrics_data.get('avg_loss_pct'),
                metrics_data.get('initial_capital'),
                metrics_data.get('final_equity'),
                metrics_data.get('net_profit'),
                metrics_data.get('mlflow_run_id')
            ))
            result_id = cur.fetchone()[0]
            conn.commit()
            logger.info(f"✓ Backtest results inserted successfully with ID: {result_id}")
            sharpe = metrics_data.get('sharpe_ratio', 0) or 0
            roi = metrics_data.get('roi', 0) or 0
            logger.info(f"  Metrics: Trades={metrics_data.get('total_trades', 0)}, "
                       f"Sharpe={sharpe:.4f}, "
                       f"ROI={roi:.2f}%")
            return result_id
        except Exception as e:
            conn.rollback()
            logger.error(f"Error inserting backtest results: {e}", exc_info=True)
            return None
        finally:
            self.pool.putconn(conn)
    
    def insert_trade(self, trade_data):
        """Insert a trade record"""
        if not self.pool:
            logger.warning("No database pool available, skipping trade insertion")
            return None
        
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            
            # Verify trades table exists
            cur.execute("""
                SELECT EXISTS (
                    SELECT FROM information_schema.tables 
                    WHERE table_schema = 'public' 
                    AND table_name = 'trades'
                );
            """)
            table_exists = cur.fetchone()[0]
            
            if not table_exists:
                logger.error("❌ 'trades' table does not exist! Creating it now...")
                cur.execute("""
                    CREATE TABLE IF NOT EXISTS trades (
                        id SERIAL PRIMARY KEY,
                        timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                        symbol VARCHAR(50) NOT NULL,
                        direction VARCHAR(10) NOT NULL,
                        quantity DECIMAL(18, 8) NOT NULL,
                        entry_price DECIMAL(18, 2) NOT NULL,
                        stop_loss DECIMAL(18, 2),
                        take_profit DECIMAL(18, 2),
                        atr_value DECIMAL(18, 2),
                        status VARCHAR(20) DEFAULT 'open',
                        exit_price DECIMAL(18, 2),
                        exit_timestamp TIMESTAMPTZ,
                        pnl DECIMAL(18, 2),
                        daily_trade_number INTEGER,
                        mlflow_run_id VARCHAR(255)
                    );
                """)
                conn.commit()
                logger.info("✓ Trades table created")
            
            cur.execute("""
                INSERT INTO trades (
                    symbol, direction, quantity, entry_price, stop_loss, 
                    take_profit, atr_value, daily_trade_number, mlflow_run_id
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
                RETURNING id;
            """, (
                trade_data.get('symbol'),
                trade_data.get('direction'),
                trade_data.get('quantity'),
                trade_data.get('entry_price'),
                trade_data.get('stop_loss'),
                trade_data.get('take_profit'),
                trade_data.get('atr_value'),
                trade_data.get('daily_trade_number'),
                trade_data.get('mlflow_run_id')
            ))
            trade_id = cur.fetchone()[0]
            conn.commit()
            return trade_id
        except Exception as e:
            conn.rollback()
            logger.error(f"Error inserting trade: {e}", exc_info=True)
            return None
        finally:
            self.pool.putconn(conn)

# Historical Data Collector
class HistoricalDataCollector:
    """Collect and store historical BTC data in TimescaleDB"""
    
    def __init__(self, db: TimescaleDB, api_key: str, api_secret: str):
        self.db = db
        self.data_client = CryptoHistoricalDataClient(api_key, api_secret)
        self._create_ohlcv_table()
    
    def _create_ohlcv_table(self):
        """Create OHLCV table in TimescaleDB"""
        conn = self.db.pool.getconn()
        try:
            cur = conn.cursor()
            cur.execute("""
                CREATE TABLE IF NOT EXISTS ohlcv_data (
                    timestamp TIMESTAMPTZ NOT NULL,
                    symbol VARCHAR(20) NOT NULL,
                    timeframe VARCHAR(10) NOT NULL,
                    open DECIMAL(20, 8),
                    high DECIMAL(20, 8),
                    low DECIMAL(20, 8),
                    close DECIMAL(20, 8),
                    volume DECIMAL(30, 8),
                    PRIMARY KEY (timestamp, symbol, timeframe)
                );
            """)
            
            try:
                cur.execute("SELECT create_hypertable('ohlcv_data', 'timestamp', if_not_exists => TRUE);")
            except Exception:
                logger.warning("Could not create hypertable for ohlcv_data")
            
            cur.execute("""
                CREATE INDEX IF NOT EXISTS idx_ohlcv_symbol_timeframe 
                ON ohlcv_data (symbol, timeframe, timestamp DESC);
            """)
            
            conn.commit()
            logger.info("OHLCV table created/verified")
        except Exception as e:
            conn.rollback()
            logger.error(f"Error creating OHLCV table: {e}")
        finally:
            self.db.pool.putconn(conn)
    
    def _normalize_symbol(self, symbol: str) -> str:
        """Normalize symbol format (BTC/USD -> BTCUSD)"""
        # Convert BTC/USD format to BTCUSD
        return symbol.replace('/', '').replace('-', '').upper()
    
    def collect_historical_data(self, symbol: str, start_date: str, end_date: str, 
                               timeframe: str = '5Min'):
        """Collect historical data from Alpaca and store in TimescaleDB"""
        timeframe_map = {
            '1Min': TimeFrame(1, TimeFrameUnit.Minute),
            '5Min': TimeFrame(5, TimeFrameUnit.Minute),
            '15Min': TimeFrame(15, TimeFrameUnit.Minute),
            '1Hour': TimeFrame(1, TimeFrameUnit.Hour),
            '1Day': TimeFrame(1, TimeFrameUnit.Day)
        }
        
        tf = timeframe_map.get(timeframe, TimeFrame(5, TimeFrameUnit.Minute))
        
        start_dt = datetime.strptime(start_date, '%Y-%m-%d').replace(tzinfo=pytz.UTC)
        end_dt = datetime.strptime(end_date, '%Y-%m-%d').replace(tzinfo=pytz.UTC)
        
        # Normalize symbol for storage (BTC/USD -> BTCUSD)
        normalized_symbol = self._normalize_symbol(symbol)
        
        logger.info(f"Collecting {symbol} data from {start_date} to {end_date} ({timeframe})")
        logger.info(f"Storing as symbol: {normalized_symbol}")
        
        current_start = start_dt
        total_bars = 0
        
        while current_start < end_dt:
            chunk_end = min(current_start + timedelta(days=30), end_dt)
            
            try:
                request_params = CryptoBarsRequest(
                    symbol_or_symbols=[symbol],
                    timeframe=tf,
                    start=current_start,
                    end=chunk_end,
                    limit=1000
                )
                
                barset = self.data_client.get_crypto_bars(request_params)
                
                # Check what symbols Alpaca actually returned
                if barset and barset.data:
                    actual_symbols = list(barset.data.keys())
                    logger.debug(f"Alpaca returned symbols: {actual_symbols}")
                    # Use the first symbol returned by Alpaca if our symbol isn't found
                    if symbol not in barset.data:
                        if actual_symbols:
                            symbol_to_use = actual_symbols[0]
                            logger.info(f"Using symbol from Alpaca response: {symbol_to_use}")
                        else:
                            logger.warning(f"No data for {symbol} from {current_start} to {chunk_end}")
                            current_start = chunk_end
                            continue
                    else:
                        symbol_to_use = symbol
                else:
                    logger.warning(f"No data for {symbol} from {current_start} to {chunk_end}")
                    current_start = chunk_end
                    continue
                
                df = barset.df.reset_index()
                df = df.rename(columns={
                    'open': 'open',
                    'high': 'high',
                    'low': 'low',
                    'close': 'close',
                    'volume': 'volume'
                })
                df = df.set_index('timestamp')
                
                # Store in database with normalized symbol
                conn = self.db.pool.getconn()
                try:
                    cur = conn.cursor()
                    for idx, row in df.iterrows():
                        cur.execute("""
                            INSERT INTO ohlcv_data 
                            (timestamp, symbol, timeframe, open, high, low, close, volume)
                            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                            ON CONFLICT (timestamp, symbol, timeframe) 
                            DO UPDATE SET
                                open = EXCLUDED.open,
                                high = EXCLUDED.high,
                                low = EXCLUDED.low,
                                close = EXCLUDED.close,
                                volume = EXCLUDED.volume;
                        """, (
                            idx, normalized_symbol, timeframe,
                            float(row['open']), float(row['high']),
                            float(row['low']), float(row['close']),
                            float(row['volume'])
                        ))
                    conn.commit()
                    total_bars += len(df)
                    logger.info(f"Stored {len(df)} bars. Total: {total_bars}")
                except Exception as e:
                    conn.rollback()
                    logger.error(f"Error storing data: {e}")
                finally:
                    self.db.pool.putconn(conn)
                
                current_start = chunk_end
                time.sleep(0.5)  # Rate limiting
                
            except Exception as e:
                logger.error(f"Error fetching data: {e}")
                time.sleep(5)
                continue
        
        logger.info(f"Collection complete! Total bars stored: {total_bars}")
        return total_bars
    
    def get_historical_data_from_db(self, symbol: str, start_date: str, 
                                    end_date: str, timeframe: str = '5Min') -> pd.DataFrame:
        """Retrieve historical data from TimescaleDB"""
        conn = self.db.pool.getconn()
        try:
            # First, check what symbols actually exist in the database
            cur = conn.cursor()
            cur.execute("SELECT DISTINCT symbol FROM ohlcv_data LIMIT 10;")
            existing_symbols = [row[0] for row in cur.fetchall()]
            logger.info(f"Symbols found in database: {existing_symbols}")
            logger.info(f"Looking for symbol: {symbol} (normalized: {self._normalize_symbol(symbol)})")
            
            # Also check what timeframes exist for debugging
            cur.execute("SELECT DISTINCT timeframe FROM ohlcv_data;")
            existing_timeframes = [row[0] for row in cur.fetchall()]
            logger.info(f"Timeframes found in database: {existing_timeframes}")
            
            # Try to find matching symbol (normalized or original format)
            normalized_symbol = self._normalize_symbol(symbol)
            symbol_to_use = None
            
            # Check if normalized symbol exists
            if normalized_symbol in existing_symbols:
                symbol_to_use = normalized_symbol
                logger.info(f"✓ Found exact match: Using normalized symbol '{symbol_to_use}'")
            # Check if original symbol exists
            elif symbol in existing_symbols:
                symbol_to_use = symbol
                logger.info(f"✓ Found exact match: Using original symbol format '{symbol_to_use}'")
            # Try to find any symbol that matches when normalized
            else:
                for db_symbol in existing_symbols:
                    db_normalized = self._normalize_symbol(db_symbol)
                    if db_normalized == normalized_symbol:
                        symbol_to_use = db_symbol
                        logger.info(f"✓ Found normalized match: '{symbol}' -> '{symbol_to_use}' (DB has '{db_symbol}', normalized to '{db_normalized}')")
                        break
            
            if symbol_to_use is None:
                logger.warning(f"✗ No matching symbol found for '{symbol}' (normalized: '{normalized_symbol}')")
                logger.warning(f"Available symbols in DB: {existing_symbols}")
                return None
            
            # Convert date strings to proper format for PostgreSQL
            # Use PostgreSQL's date casting for reliability
            try:
                # Parse dates and ensure they're timezone-aware
                start_dt = pd.to_datetime(start_date)
                if start_dt.tz is None:
                    start_dt = start_dt.tz_localize('UTC')
                else:
                    start_dt = start_dt.tz_convert('UTC')
                
                end_dt = pd.to_datetime(end_date)
                if end_dt.tz is None:
                    end_dt = end_dt.tz_localize('UTC')
                else:
                    end_dt = end_dt.tz_convert('UTC')
                
                # Add one day to end_date to include the entire end day
                end_dt = end_dt + pd.Timedelta(days=1)
            except Exception as e:
                logger.error(f"Error parsing dates: {e}")
                return None
            
            query = """
                SELECT timestamp, open, high, low, close, volume
                FROM ohlcv_data
                WHERE symbol = %s 
                AND timeframe = %s
                AND timestamp >= %s 
                AND timestamp < %s
                ORDER BY timestamp ASC;
            """
            logger.info(f"Executing query: symbol='{symbol_to_use}', timeframe='{timeframe}', start={start_dt}, end={end_dt}")
            cur.execute(query, (symbol_to_use, timeframe, start_dt, end_dt))
            rows = cur.fetchall()
            colnames = [desc[0] for desc in cur.description]
            cur.close()
            
            if len(rows) == 0:
                logger.warning(f"No data found for '{symbol_to_use}' from {start_date} to {end_date} with timeframe {timeframe}")
                # Debug: Check if data exists for this symbol at all
                try:
                    cur2 = conn.cursor()
                    cur2.execute("SELECT MIN(timestamp), MAX(timestamp), COUNT(*) FROM ohlcv_data WHERE symbol = %s AND timeframe = %s;", 
                                (symbol_to_use, timeframe))
                    debug_info = cur2.fetchone()
                    cur2.close()
                    if debug_info and debug_info[2] > 0:
                        logger.info(f"Debug: Symbol '{symbol_to_use}' has {debug_info[2]} total bars")
                        logger.info(f"Debug: Available date range: {debug_info[0]} to {debug_info[1]}")
                        logger.info(f"Debug: Requested date range: {start_dt} to {end_dt}")
                        # Check if there's any overlap
                        if debug_info[0] and debug_info[1]:
                            if end_dt < debug_info[0] or start_dt > debug_info[1]:
                                logger.warning(f"⚠️  Requested date range ({start_date} to {end_date}) does NOT overlap with available data ({debug_info[0]} to {debug_info[1]})")
                            else:
                                logger.info(f"✓ Date ranges overlap, but no data returned. This might be a timezone or date format issue.")
                    else:
                        logger.warning(f"Debug: No data found for symbol '{symbol_to_use}' with timeframe '{timeframe}' at all!")
                except Exception as debug_e:
                    logger.error(f"Error in debug query: {debug_e}")
                return None
            
            df = pd.DataFrame(rows, columns=colnames)
            df['timestamp'] = pd.to_datetime(df['timestamp'])
            
            # Convert Decimal columns to float (PostgreSQL DECIMAL returns as Decimal type)
            numeric_columns = ['open', 'high', 'low', 'close', 'volume']
            for col in numeric_columns:
                if col in df.columns:
                    df[col] = df[col].astype(float)
            
            df.set_index('timestamp', inplace=True)
            logger.info(f"✓ Successfully retrieved {len(df)} bars from database for '{symbol_to_use}'")
            return df
        except Exception as e:
            logger.error(f"Error retrieving data from database: {e}", exc_info=True)
            return None
        finally:
            self.db.pool.putconn(conn)

# Base Trading Bot Logic
class BaseCryptoTradingBot:
    def __init__(self, symbol='BTCUSD', max_daily_trades=3, quantity=0.001):
        self.symbol = symbol
        self.max_daily_trades = max_daily_trades
        self.daily_trades = 0
        self.last_trade_date = None
        self.atr_length = 14
        self.fvg_lookback = 3
        self.sweep_lookback = 3
        self.quantity = quantity
        self.stop_loss_pct = 0.02
        self.take_profit_pct = 0.04
        
    def reset_daily_counter(self):
        """Reset the daily trade counter if it's a new day"""
        current_date = datetime.now().date()
        if self.last_trade_date is None or current_date > self.last_trade_date:
            logger.info(f"New trading day: {current_date}. Resetting daily trade counter.")
            self.daily_trades = 0
            self.last_trade_date = current_date

    def calculate_atr(self, df: pd.DataFrame, length: int = 14) -> pd.Series:
        """Calculate Average True Range"""
        high = df['high']
        low = df['low']
        close = df['close'].shift(1)
        
        tr1 = high - low
        tr2 = abs(high - close)
        tr3 = abs(low - close)
        
        tr = pd.DataFrame({'tr1': tr1, 'tr2': tr2, 'tr3': tr3}).max(axis=1)
        atr = tr.rolling(window=length).mean()
        
        return atr

    def detect_sweep(self, df: pd.DataFrame):
        """Detect liquidity sweeps"""
        swing_low = df['low'].rolling(window=self.sweep_lookback).min().shift(2)
        swing_high = df['high'].rolling(window=self.sweep_lookback).max().shift(2)
        
        bullish_sweep = (df['low'].shift(2) == swing_low) & \
                         (df['low'].shift(1) < df['low'].shift(2)) & \
                         (df['close'] > df['high'].shift(2))
        
        bearish_sweep = (df['high'].shift(2) == swing_high) & \
                         (df['high'].shift(1) > df['high'].shift(2)) & \
                         (df['close'] < df['low'].shift(2))
        
        return bullish_sweep, bearish_sweep

    def detect_fvg(self, df: pd.DataFrame):
        """Detect Fair Value Gaps"""
        highest_high = df['high'].shift(1).rolling(window=self.fvg_lookback).max()
        lowest_low = df['low'].shift(1).rolling(window=self.fvg_lookback).min()
        
        bullish_fvg = df['low'] > highest_high
        bearish_fvg = df['high'] < lowest_low
        
        return bullish_fvg, bearish_fvg

    def check_for_signals(self, df: pd.DataFrame):
        """Check for trading signals in the data"""
        if df is None or len(df) < self.fvg_lookback + self.sweep_lookback + 5:
            logger.warning(f"Insufficient data for signal detection. Have {len(df) if df is not None else 0} bars")
            return None
        
        # Make a deep copy to avoid SettingWithCopyWarning when modifying
        df = df.copy(deep=True)
        
        # Calculate indicators - use .loc to avoid SettingWithCopyWarning
        atr_series = self.calculate_atr(df, self.atr_length)
        df = df.assign(atr=atr_series)
        bullish_sweep, bearish_sweep = self.detect_sweep(df)
        bullish_fvg, bearish_fvg = self.detect_fvg(df)
        
        # Get latest signals
        latest = df.iloc[-1]
        
        # Convert price to float (handle Decimal types from database)
        try:
            price_value = float(latest['close'])
        except (TypeError, ValueError):
            price_value = 0.0
        
        # Handle NaN ATR - convert to float and replace with 0 if NaN
        try:
            atr_value = float(latest['atr'])
        except (TypeError, ValueError):
            atr_value = 0.0
        
        if pd.isna(atr_value) or atr_value is None:
            atr_value = 0.0
        
        signals = {
            'bullish_sweep': bullish_sweep.iloc[-1] if len(bullish_sweep) > 0 else False,
            'bearish_sweep': bearish_sweep.iloc[-1] if len(bearish_sweep) > 0 else False,
            'bullish_fvg': bullish_fvg.iloc[-1] if len(bullish_fvg) > 0 else False,
            'bearish_fvg': bearish_fvg.iloc[-1] if len(bearish_fvg) > 0 else False,
            'price': price_value,
            'atr': atr_value
        }
        
        # Only log if there's an actual signal to reduce verbosity
        if signals['bullish_sweep'] or signals['bearish_sweep'] or signals['bullish_fvg'] or signals['bearish_fvg']:
            logger.info(f"Signal detected: Price=${signals['price']:.2f}, "
                       f"BullishSweep={signals['bullish_sweep']}, BearishSweep={signals['bearish_sweep']}, "
                       f"BullishFVG={signals['bullish_fvg']}, BearishFVG={signals['bearish_fvg']}")
        
        return signals

# Backtest Bot using TimescaleDB
class TimescaleDBBacktestBot(BaseCryptoTradingBot):
    """Backtest bot that uses historical data from TimescaleDB"""
    
    def __init__(self, db: TimescaleDB, data_collector: HistoricalDataCollector, **kwargs):
        super().__init__(**kwargs)
        self.db = db
        self.data_collector = data_collector
        self.backtest_results = []
        self.current_mlflow_run = None
        self.positions = []  # Track open positions
        self.equity_curve = []  # Track equity over time
        self.initial_capital = 10000.0  # Starting capital
        self.current_capital = self.initial_capital
    
    def execute_trade(self, direction: str, price: float, atr_value: float, timestamp=None):
        """Simulate trade execution for backtesting"""
        if self.daily_trades >= self.max_daily_trades:
            logger.info(f"Maximum daily trades reached: {self.daily_trades}/{self.max_daily_trades}")
            return
        
        # Validate inputs - convert to float first to handle Decimal types
        try:
            price = float(price)
        except (TypeError, ValueError):
            logger.warning(f"Invalid price type: {type(price)}, value: {price}, skipping trade")
            return
        
        if price is None or np.isnan(price) or price <= 0:
            logger.warning(f"Invalid price: {price}, skipping trade")
            return
        
        # Handle NaN ATR - convert to float first
        try:
            atr_value = float(atr_value) if atr_value is not None else 0.0
        except (TypeError, ValueError):
            atr_value = 0.0
        
        atr_valid = not np.isnan(atr_value) and atr_value > 0
        
        # Calculate stop loss and take profit
        if direction == 'long':
            stop_price = price * (1 - self.stop_loss_pct)
            if atr_valid:
                take_profit = min(
                    price * (1 + self.take_profit_pct),
                    price + (2 * atr_value)
                )
            else:
                take_profit = price * (1 + self.take_profit_pct)
        else:  # short
            stop_price = price * (1 + self.stop_loss_pct)
            if atr_valid:
                take_profit = max(
                    price * (1 - self.take_profit_pct),
                    price - (2 * atr_value)
                )
            else:
                take_profit = price * (1 - self.take_profit_pct)
        
        logger.info(f"BACKTEST: Executed {direction.upper()} trade: {self.quantity} {self.symbol} at ${price:.2f}")
        logger.info(f"  Stop Loss: ${stop_price:.2f}, Take Profit: ${take_profit:.2f}")
        
        # Track position
        position = {
            'direction': direction,
            'entry_price': price,
            'stop_loss': stop_price,
            'take_profit': take_profit,
            'quantity': self.quantity,
            'entry_time': timestamp or datetime.now(),
            'entry_capital': self.current_capital
        }
        self.positions.append(position)
        
        # Save to database
        trade_id = None
        if self.db:
            # Ensure ATR is a valid float (handle NaN)
            atr_for_db = float(atr_value) if (atr_value is not None and not np.isnan(atr_value)) else 0.0
            
            trade_id = self.db.insert_trade({
                'symbol': self.symbol,
                'direction': direction,
                'quantity': float(self.quantity),
                'entry_price': float(price),
                'stop_loss': float(stop_price),
                'take_profit': float(take_profit),
                'atr_value': atr_for_db,
                'daily_trade_number': self.daily_trades + 1,
                'mlflow_run_id': self.current_mlflow_run.info.run_id if self.current_mlflow_run else None
            })
        
        self.daily_trades += 1
        self.backtest_results.append({
            'direction': direction,
            'entry_price': price,
            'stop_loss': stop_price,
            'take_profit': take_profit,
            'trade_id': trade_id,
            'entry_time': timestamp or datetime.now()
        })
    
    def calculate_metrics(self, df: pd.DataFrame):
        """Calculate performance metrics including Sharpe ratio"""
        if len(self.backtest_results) == 0:
            return {}
        
        # Calculate returns for each trade
        returns = []
        closed_trades = []
        
        for i, trade in enumerate(self.backtest_results):
            entry_price = trade['entry_price']
            entry_time = trade['entry_time']
            
            # Find closest index (handle timestamp matching)
            try:
                if entry_time in df.index:
                    entry_idx = df.index.get_loc(entry_time)
                else:
                    # Find closest timestamp
                    entry_idx = df.index.searchsorted(entry_time)
                    if entry_idx >= len(df):
                        entry_idx = len(df) - 1
            except Exception:
                continue
            
            # Find exit (stop loss or take profit hit)
            direction = trade['direction']
            stop_loss = trade['stop_loss']
            take_profit = trade['take_profit']
            
            exit_price = None
            exit_reason = None
            
            # Check subsequent bars for exit
            for j in range(entry_idx + 1, min(entry_idx + 100, len(df))):
                bar = df.iloc[j]
                
                if direction == 'long':
                    # Check stop loss
                    if bar['low'] <= stop_loss:
                        exit_price = stop_loss
                        exit_reason = 'stop_loss'
                        break
                    # Check take profit
                    elif bar['high'] >= take_profit:
                        exit_price = take_profit
                        exit_reason = 'take_profit'
                        break
                else:  # short
                    # Check stop loss
                    if bar['high'] >= stop_loss:
                        exit_price = stop_loss
                        exit_reason = 'stop_loss'
                        break
                    # Check take profit
                    elif bar['low'] <= take_profit:
                        exit_price = take_profit
                        exit_reason = 'take_profit'
                        break
            
            # If no exit found, use last bar price
            if exit_price is None:
                exit_price = df.iloc[-1]['close']
                exit_reason = 'end_of_data'
            
            # Calculate return
            if direction == 'long':
                trade_return = (exit_price - entry_price) / entry_price
            else:  # short
                trade_return = (entry_price - exit_price) / entry_price
            
            returns.append(trade_return)
            closed_trades.append({
                'entry_price': entry_price,
                'exit_price': exit_price,
                'direction': direction,
                'return': trade_return,
                'exit_reason': exit_reason
            })
        
        if len(returns) == 0:
            return {}
        
        returns_array = np.array(returns)
        
        # Calculate metrics
        total_return = np.sum(returns_array)
        total_trades = len(returns)
        winning_trades = len([r for r in returns if r > 0])
        losing_trades = len([r for r in returns if r < 0])
        win_rate = winning_trades / total_trades if total_trades > 0 else 0
        
        avg_return = np.mean(returns_array)
        std_return = np.std(returns_array)
        
        # Sharpe ratio (annualized, assuming 252 trading days)
        # For 5-min bars: 288 bars per day, so annualization factor
        bars_per_day = 288  # 5-min bars in a day
        trading_days = len(df) / bars_per_day
        sharpe_ratio = (avg_return / std_return * np.sqrt(bars_per_day)) if std_return > 0 else 0
        
        # Maximum drawdown
        cumulative_returns = np.cumsum(returns_array)
        running_max = np.maximum.accumulate(cumulative_returns)
        drawdown = cumulative_returns - running_max
        max_drawdown = np.min(drawdown) if len(drawdown) > 0 else 0
        
        # Profit factor
        gross_profit = sum([r for r in returns if r > 0])
        gross_loss = abs(sum([r for r in returns if r < 0]))
        profit_factor = gross_profit / gross_loss if gross_loss > 0 else float('inf')
        
        # Average win/loss
        avg_win = np.mean([r for r in returns if r > 0]) if winning_trades > 0 else 0
        avg_loss = np.mean([r for r in returns if r < 0]) if losing_trades > 0 else 0
        
        # Final equity
        final_equity = self.initial_capital * (1 + total_return)
        
        metrics = {
            'total_trades': total_trades,
            'winning_trades': winning_trades,
            'losing_trades': losing_trades,
            'win_rate': win_rate,
            'total_return': total_return,
            'total_return_pct': total_return * 100,
            'avg_return': avg_return,
            'avg_return_pct': avg_return * 100,
            'sharpe_ratio': sharpe_ratio,
            'max_drawdown': max_drawdown,
            'max_drawdown_pct': max_drawdown * 100,
            'profit_factor': profit_factor,
            'avg_win': avg_win,
            'avg_win_pct': avg_win * 100,
            'avg_loss': avg_loss,
            'avg_loss_pct': avg_loss * 100,
            'initial_capital': self.initial_capital,
            'final_equity': final_equity,
            'net_profit': final_equity - self.initial_capital,
            'roi': (final_equity - self.initial_capital) / self.initial_capital * 100
        }
        
        return metrics
    
    def run_backtest_from_db(self, start_date: str, end_date: str, timeframe: str = '5Min'):
        """Run backtest using data from TimescaleDB"""
        logger.info(f"Starting backtest from {start_date} to {end_date}")
        logger.info(f"Requested symbol: {self.symbol}")
        
        # Try to get data - the function will automatically find the correct symbol format
        # The get_historical_data_from_db method handles symbol matching internally
        df = self.data_collector.get_historical_data_from_db(
            self.symbol, start_date, end_date, timeframe
        )
        
        # If not found, try with alternative symbol formats as fallback
        if df is None or len(df) == 0:
            logger.warning(f"Initial query with '{self.symbol}' returned no data. Trying alternative formats...")
            # Try alternative symbol formats
            alt_symbols = ['BTC/USD', 'BTCUSD', 'BTC-USD']
            for alt_symbol in alt_symbols:
                if alt_symbol != self.symbol:
                    logger.info(f"Trying alternative symbol format: {alt_symbol}")
                    df = self.data_collector.get_historical_data_from_db(
                        alt_symbol, start_date, end_date, timeframe
                    )
                    if df is not None and len(df) > 0:
                        logger.info(f"✓ Found data with symbol format: {alt_symbol}")
                        # Update self.symbol to match what was found
                        self.symbol = alt_symbol
                        break
        
        if df is None or len(df) == 0:
            logger.error("No data found in database. Run data collection first!")
            logger.error(f"Tried symbol: {self.symbol} and alternatives: BTC/USD, BTCUSD, BTC-USD")
            return None
        
        logger.info(f"Backtesting on {len(df)} bars from database")
        
        # MLflow experiment
        mlflow.set_experiment("btc_backtest_db")
        self.current_mlflow_run = mlflow.start_run()
        
        try:
            mlflow.log_param("symbol", self.symbol)
            mlflow.log_param("start_date", start_date)
            mlflow.log_param("end_date", end_date)
            mlflow.log_param("timeframe", timeframe)
            mlflow.log_param("max_daily_trades", self.max_daily_trades)
            mlflow.log_param("stop_loss_pct", self.stop_loss_pct)
            mlflow.log_param("take_profit_pct", self.take_profit_pct)
            mlflow.log_param("initial_capital", self.initial_capital)
            
            # Walk-forward backtest
            # Start from index that ensures we have enough lookback data
            min_lookback = max(50, self.fvg_lookback + self.sweep_lookback + 5)
            start_idx = min_lookback
            
            for i in range(start_idx, len(df)):
                # Ensure we always have at least 50 bars, starting from 0 if needed
                lookback_start = max(0, i - 50)
                lookback_data = df.iloc[lookback_start:i+1].copy()  # +1 to include current bar
                signals = self.check_for_signals(lookback_data)
                
                if signals:
                    current_timestamp = df.index[i]
                    if signals['bullish_sweep'] and signals['bullish_fvg']:
                        self.execute_trade('long', signals['price'], signals['atr'], current_timestamp)
                    elif signals['bearish_sweep'] and signals['bearish_fvg']:
                        self.execute_trade('short', signals['price'], signals['atr'], current_timestamp)
                
                # Progress logging
                if i % 100 == 0:
                    logger.info(f"Backtest progress: {i}/{len(df)} bars ({i/len(df)*100:.1f}%)")
            
            # Calculate metrics
            metrics = self.calculate_metrics(df)
            
            logger.info(f"\n{'='*60}")
            logger.info("BACKTEST RESULTS")
            logger.info(f"{'='*60}")
            logger.info(f"Total Trades: {metrics.get('total_trades', 0)}")
            logger.info(f"Winning Trades: {metrics.get('winning_trades', 0)}")
            logger.info(f"Losing Trades: {metrics.get('losing_trades', 0)}")
            logger.info(f"Win Rate: {metrics.get('win_rate', 0)*100:.2f}%")
            logger.info(f"\nPerformance Metrics:")
            logger.info(f"Total Return: {metrics.get('total_return_pct', 0):.2f}%")
            logger.info(f"ROI: {metrics.get('roi', 0):.2f}%")
            logger.info(f"Initial Capital: ${metrics.get('initial_capital', 0):,.2f}")
            logger.info(f"Final Equity: ${metrics.get('final_equity', 0):,.2f}")
            logger.info(f"Net Profit: ${metrics.get('net_profit', 0):,.2f}")
            logger.info(f"\nRisk Metrics:")
            logger.info(f"Sharpe Ratio: {metrics.get('sharpe_ratio', 0):.4f}")
            logger.info(f"Max Drawdown: {metrics.get('max_drawdown_pct', 0):.2f}%")
            logger.info(f"Profit Factor: {metrics.get('profit_factor', 0):.4f}")
            logger.info(f"Average Win: {metrics.get('avg_win_pct', 0):.2f}%")
            logger.info(f"Average Loss: {metrics.get('avg_loss_pct', 0):.2f}%")
            logger.info(f"{'='*60}\n")
            
            # Log to MLflow
            mlflow.log_metric("total_trades", metrics.get('total_trades', 0))
            mlflow.log_metric("winning_trades", metrics.get('winning_trades', 0))
            mlflow.log_metric("losing_trades", metrics.get('losing_trades', 0))
            mlflow.log_metric("win_rate", metrics.get('win_rate', 0))
            mlflow.log_metric("total_return_pct", metrics.get('total_return_pct', 0))
            mlflow.log_metric("roi", metrics.get('roi', 0))
            mlflow.log_metric("final_equity", metrics.get('final_equity', 0))
            mlflow.log_metric("net_profit", metrics.get('net_profit', 0))
            mlflow.log_metric("sharpe_ratio", metrics.get('sharpe_ratio', 0))
            mlflow.log_metric("max_drawdown_pct", metrics.get('max_drawdown_pct', 0))
            mlflow.log_metric("profit_factor", metrics.get('profit_factor', 0))
            mlflow.log_metric("avg_win_pct", metrics.get('avg_win_pct', 0))
            mlflow.log_metric("avg_loss_pct", metrics.get('avg_loss_pct', 0))
            
            # Store metrics in TimescaleDB for Grafana visualization
            if self.db:
                metrics_for_db = metrics.copy()
                metrics_for_db.update({
                    'start_date': start_date,
                    'end_date': end_date,
                    'symbol': self.symbol,
                    'timeframe': timeframe,
                    'mlflow_run_id': self.current_mlflow_run.info.run_id if self.current_mlflow_run else None
                })
                result_id = self.db.insert_backtest_results(metrics_for_db)
                if result_id:
                    logger.info(f"Backtest metrics saved to TimescaleDB with ID: {result_id}")
            
            return metrics
            
        finally:
            mlflow.end_run()

# Configuration
class BacktestConfig:
    def __init__(self):
        # Alpaca credentials
        self.ALPACA_API_KEY = os.getenv('ALPACA_API_KEY', 'PKSWFXHIT7WAESKFYXTTJ6DKUE')
        self.ALPACA_API_SECRET = os.getenv('ALPACA_API_SECRET', 'A4nDUtAxdWijWjmg4zPVXcPeciaKhfkzwJ2wVF4gS5sg')
        
        # TimescaleDB configuration
        self.TIMESCALEDB_URL = os.getenv(
            'TIMESCALEDB_URL', 
            'postgresql://rayhan:12102801Rr@timescaledb:5432/arafatdb'
        )
        
        # MLflow configuration
        self.MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI', 'http://mlflow:5000')
        
        # Loki configuration
        self.LOKI_URL = os.getenv('LOKI_URL', 'http://loki:3100/loki/api/v1/push')
        
        # Initialize connections
        self.db = TimescaleDB(self.TIMESCALEDB_URL)
        mlflow.set_tracking_uri(self.MLFLOW_TRACKING_URI)
        
        # Setup logging with Loki
        global logger
        logger = setup_logging(
            level=logging.INFO,
            loki_url=self.LOKI_URL,
            loki_labels={'service': 'btc_backtest'}
        )

# Main execution
if __name__ == "__main__":
    config = BacktestConfig()
    
    # Create data collector
    collector = HistoricalDataCollector(
        db=config.db,
        api_key=config.ALPACA_API_KEY,
        api_secret=config.ALPACA_API_SECRET
    )
    
    # STEP 1: Collect historical data (UNCOMMENT AND RUN THIS FIRST!)
    print("="*60)
    print("STEP 1: BTC Historical Data Collection")
    print("="*60)
    print("\n⚠️  IMPORTANT: Uncomment the lines below to collect historical data FIRST!")
    print("This will take 30-60 minutes depending on date range.\n")
    
    # ⬇️ UNCOMMENT THE LINES BELOW TO COLLECT DATA ⬇️
    # collector.collect_historical_data(
    #     symbol='BTCUSD',
    #     start_date='2020-01-01',  # Start date
    #     end_date='2024-12-31',     # End date
    #     timeframe='5Min'           # 5-minute bars
    # )
    # ⬆️ UNCOMMENT THE LINES ABOVE TO COLLECT DATA ⬆️
    
    # STEP 2: Run backtest using collected data
    print("\n" + "="*60)
    print("STEP 2: BTC Backtest")
    print("="*60)
    print("\n⚠️  Make sure you've collected data first (Step 1)!\n")
    
    # Check if data exists before running backtest
    # Try both symbol formats (BTCUSD and BTC/USD)
    test_df = collector.get_historical_data_from_db(
        'BTCUSD', '2021-01-01', '2022-12-31', '5Min'
    )
    
    # If not found, try with slash format
    if test_df is None or len(test_df) == 0:
        logger.info("Trying with BTC/USD format...")
        test_df = collector.get_historical_data_from_db(
            'BTC/USD', '2021-01-01', '2022-12-31', '5Min'
        )
    
    if test_df is None or len(test_df) == 0:
        print("❌ ERROR: No data found in database!")
        print("\nPlease run data collection first:")
        print("1. Uncomment the collector.collect_historical_data() lines above")
        print("2. Run this cell again")
        print("3. Wait for data collection to complete (30-60 minutes)")
        print("4. Then run the backtest section below")
    else:
        print(f"✅ Found {len(test_df)} bars in database. Running backtest...\n")
        
        backtest_bot = TimescaleDBBacktestBot(
            db=config.db,
            data_collector=collector,
            symbol='BTCUSD',
            max_daily_trades=3,
            quantity=0.001
        )
        
        # Run backtest (use same dates as data collection)
        metrics = backtest_bot.run_backtest_from_db(
            start_date='2021-01-01',
            end_date='2022-12-31',
            timeframe='5Min'
        )
        
        if metrics:
            print(f"\n{'='*60}")
            print("BACKTEST SUMMARY")
            print(f"{'='*60}")
            print(f"Total Trades: {metrics.get('total_trades', 0)}")
            print(f"Long Trades: {len([t for t in backtest_bot.backtest_results if t['direction'] == 'long'])}")
            print(f"Short Trades: {len([t for t in backtest_bot.backtest_results if t['direction'] == 'short'])}")
            print(f"\nSharpe Ratio: {metrics.get('sharpe_ratio', 0):.4f}")
            print(f"Total Return: {metrics.get('total_return_pct', 0):.2f}%")
            print(f"ROI: {metrics.get('roi', 0):.2f}%")
            print(f"Max Drawdown: {metrics.get('max_drawdown_pct', 0):.2f}%")
            print(f"Profit Factor: {metrics.get('profit_factor', 0):.4f}")
            print(f"Win Rate: {metrics.get('win_rate', 0)*100:.2f}%")
            print(f"{'='*60}")
# Out:
# 2025-11-14 17:49:56,258 - WARNING - Could not create hypertable (may be regular PostgreSQL)
# 2025-11-14 17:49:56,259 - ERROR - ❌ Schema initialization error: current transaction is aborted, commands ignored until end of transaction block
# Traceback (most recent call last):
#   File "/tmp/ipykernel_6330/866869883.py", line 174, in _init_schema
#     cur.execute("""
# psycopg2.errors.InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-11-14 17:49:56,265 - INFO - ✓ Trades table created successfully (fallback)
# 2025-11-14 17:49:56,266 - INFO - TimescaleDB connection pool created
# 2025-11-14 17:49:56,269 - INFO - OHLCV table created/verified
# ============================================================
# STEP 1: BTC Historical Data Collection
# ============================================================
#
# ⚠️  IMPORTANT: Uncomment the lines below to collect historical data FIRST!
# This will take 30-60 minutes depending on date range.
#
#
# ============================================================
# STEP 2: BTC Backtest
# ============================================================
#
# ⚠️  Make sure you've collected data first (Step 1)!
#
# 2025-11-14 17:49:56,357 - INFO - Symbols found in database: ['BTC/USD']
# 2025-11-14 17:49:56,359 - INFO - Looking for symbol: BTCUSD (normalized: BTCUSD)
# 2025-11-14 17:49:56,370 - INFO - Timeframes found in database: ['5Min']
# 2025-11-14 17:49:56,371 - INFO - ✓ Found normalized match: 'BTCUSD' -> 'BTC/USD' (DB has 'BTC/USD', normalized to 'BTCUSD')
# 2025-11-14 17:49:56,384 - INFO - Executing query: symbol='BTC/USD', timeframe='5Min', start=2021-01-01 00:00:00+00:00, end=2023-01-01 00:00:00+00:00
# 2025-11-14 17:49:56,740 - INFO - ✓ Successfully retrieved 49000 bars from database for 'BTC/USD'
# ✅ Found 49000 bars in database. Running backtest...
#
# 2025-11-14 17:49:56,745 - INFO - Starting backtest from 2021-01-01 to 2022-12-31
# 2025-11-14 17:49:56,747 - INFO - Requested symbol: BTCUSD
# 2025-11-14 17:49:56,761 - INFO - Symbols found in database: ['BTC/USD']
# 2025-11-14 17:49:56,762 - INFO - Looking for symbol: BTCUSD (normalized: BTCUSD)
# 2025-11-14 17:49:56,773 - INFO - Timeframes found in database: ['5Min']
# 2025-11-14 17:49:56,775 - INFO - ✓ Found normalized match: 'BTCUSD' -> 'BTC/USD' (DB has 'BTC/USD', normalized to 'BTCUSD')
# 2025-11-14 17:49:56,777 - INFO - Executing query: symbol='BTC/USD', timeframe='5Min', start=2021-01-01 00:00:00+00:00, end=2023-01-01 00:00:00+00:00
# 2025-11-14 17:49:56,954 - INFO - ✓ Successfully retrieved 49000 bars from database for 'BTC/USD'
# 2025-11-14 17:49:56,958 - INFO - Backtesting on 49000 bars from database
# 2025-11-14 17:49:57,026 - INFO - Signal detected: Price=$29353.06, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,031 - INFO - Signal detected: Price=$29309.26, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,054 - INFO - Signal detected: Price=$29372.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,056 - INFO - Signal detected: Price=$29378.85, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,106 - INFO - Backtest progress: 100/49000 bars (0.2%)
# 2025-11-14 17:49:57,155 - INFO - Signal detected: Price=$29335.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,186 - INFO - Signal detected: Price=$29078.07, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,204 - INFO - Signal detected: Price=$29148.79, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,208 - INFO - Signal detected: Price=$29186.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,210 - INFO - Signal detected: Price=$29189.96, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,232 - INFO - Signal detected: Price=$29319.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,255 - INFO - Backtest progress: 200/49000 bars (0.4%)
# 2025-11-14 17:49:57,297 - INFO - Signal detected: Price=$29205.18, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,356 - INFO - Signal detected: Price=$29392.61, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,410 - INFO - Backtest progress: 300/49000 bars (0.6%)
# 2025-11-14 17:49:57,430 - INFO - Signal detected: Price=$29829.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,455 - INFO - Signal detected: Price=$29833.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,460 - INFO - Signal detected: Price=$29696.32, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,475 - INFO - Signal detected: Price=$29826.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,479 - INFO - Signal detected: Price=$29745.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,563 - INFO - Backtest progress: 400/49000 bars (0.8%)
# 2025-11-14 17:49:57,587 - INFO - Signal detected: Price=$32334.97, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,608 - INFO - Signal detected: Price=$32638.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,691 - INFO - Signal detected: Price=$31452.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,719 - INFO - Backtest progress: 500/49000 bars (1.0%)
# 2025-11-14 17:49:57,722 - INFO - Signal detected: Price=$32055.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,735 - INFO - Signal detected: Price=$32442.10, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:57,772 - INFO - Signal detected: Price=$32812.99, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,801 - INFO - Signal detected: Price=$32648.58, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,848 - INFO - Signal detected: Price=$33900.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,868 - INFO - Backtest progress: 600/49000 bars (1.2%)
# 2025-11-14 17:49:57,922 - INFO - Signal detected: Price=$34117.04, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:57,982 - INFO - Signal detected: Price=$33989.72, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,002 - INFO - Signal detected: Price=$33419.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,015 - INFO - Backtest progress: 700/49000 bars (1.4%)
# 2025-11-14 17:49:58,032 - INFO - Signal detected: Price=$33125.54, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,042 - INFO - Signal detected: Price=$32902.01, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,065 - INFO - Signal detected: Price=$32723.57, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,079 - INFO - Signal detected: Price=$32681.97, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,081 - INFO - Signal detected: Price=$32679.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,086 - INFO - Signal detected: Price=$33159.74, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,098 - INFO - Signal detected: Price=$33617.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,123 - INFO - Signal detected: Price=$33590.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,139 - INFO - Signal detected: Price=$33439.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,160 - INFO - Signal detected: Price=$32817.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,165 - INFO - Backtest progress: 800/49000 bars (1.6%)
# 2025-11-14 17:49:58,179 - INFO - Signal detected: Price=$32880.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,182 - INFO - Signal detected: Price=$33090.39, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,206 - INFO - Signal detected: Price=$33347.42, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,232 - INFO - Signal detected: Price=$33519.76, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,248 - INFO - Signal detected: Price=$33212.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,253 - INFO - Signal detected: Price=$33305.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,259 - INFO - Signal detected: Price=$33149.42, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,261 - INFO - Signal detected: Price=$33105.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,290 - INFO - Signal detected: Price=$33260.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,327 - INFO - Signal detected: Price=$32015.18, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,331 - INFO - Backtest progress: 900/49000 bars (1.8%)
# 2025-11-14 17:49:58,334 - INFO - Signal detected: Price=$31735.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,378 - INFO - Signal detected: Price=$30071.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,415 - INFO - Signal detected: Price=$31054.36, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,424 - INFO - Signal detected: Price=$31020.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,466 - INFO - Signal detected: Price=$32054.59, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,498 - INFO - Signal detected: Price=$32232.63, BullishSweep=True, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,499 - INFO - BACKTEST: Executed LONG trade: 0.001 BTCUSD at $32232.63
# 2025-11-14 17:49:58,500 - INFO -   Stop Loss: $31587.98, Take Profit: $32886.16
# 2025-11-14 17:49:58,506 - INFO - Backtest progress: 1000/49000 bars (2.0%)
# 2025-11-14 17:49:58,523 - INFO - Signal detected: Price=$32609.74, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,535 - INFO - Signal detected: Price=$32548.27, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,564 - INFO - Signal detected: Price=$32679.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,585 - INFO - Signal detected: Price=$33472.23, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:49:58,595 - INFO - Signal detected: Price=$33496.31, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,615 - INFO - Signal detected: Price=$33387.10, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,654 - INFO - Backtest progress: 1100/49000 bars (2.2%)
# 2025-11-14 17:49:58,717 - INFO - Signal detected: Price=$33274.48, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,733 - INFO - Signal detected: Price=$33537.59, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,758 - INFO - Signal detected: Price=$34645.81, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:58,762 - INFO - Signal detected: Price=$34443.55, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,786 - INFO - Signal detected: Price=$34582.93, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,797 - INFO - Signal detected: Price=$34395.95, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,807 - INFO - Signal detected: Price=$34445.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,811 - INFO - Signal detected: Price=$34165.33, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,823 - INFO - Backtest progress: 1200/49000 bars (2.4%)
# 2025-11-14 17:49:58,845 - INFO - Signal detected: Price=$33921.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,848 - INFO - Signal detected: Price=$33910.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,904 - INFO - Signal detected: Price=$33441.49, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,910 - INFO - Signal detected: Price=$32840.46, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,941 - INFO - Signal detected: Price=$32385.43, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,966 - INFO - Signal detected: Price=$32435.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:58,982 - INFO - Backtest progress: 1300/49000 bars (2.7%)
# 2025-11-14 17:49:59,083 - INFO - Signal detected: Price=$31986.25, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:49:59,085 - INFO - Signal detected: Price=$31919.12, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:49:59,097 - INFO - Signal detected: Price=$31709.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,145 - INFO - Backtest progress: 1400/49000 bars (2.9%)
# 2025-11-14 17:49:59,153 - INFO - Signal detected: Price=$31429.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,157 - INFO - Signal detected: Price=$31803.32, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,205 - INFO - Signal detected: Price=$31741.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,218 - INFO - Signal detected: Price=$31419.29, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,224 - INFO - Signal detected: Price=$31465.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,248 - INFO - Signal detected: Price=$31344.94, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,270 - INFO - Signal detected: Price=$31521.05, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,298 - INFO - Backtest progress: 1500/49000 bars (3.1%)
# 2025-11-14 17:49:59,304 - INFO - Signal detected: Price=$32057.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,306 - INFO - Signal detected: Price=$31951.38, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,326 - INFO - Signal detected: Price=$32176.87, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,344 - INFO - Signal detected: Price=$32275.81, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,364 - INFO - Signal detected: Price=$31999.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,370 - INFO - Signal detected: Price=$32128.17, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,381 - INFO - Signal detected: Price=$32100.22, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,424 - INFO - Signal detected: Price=$32002.30, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,443 - INFO - Signal detected: Price=$32148.14, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,449 - INFO - Backtest progress: 1600/49000 bars (3.3%)
# 2025-11-14 17:49:59,458 - INFO - Signal detected: Price=$32133.18, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,485 - INFO - Signal detected: Price=$31649.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,499 - INFO - Signal detected: Price=$31804.31, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,563 - INFO - Signal detected: Price=$31822.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,573 - INFO - Signal detected: Price=$31554.41, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,609 - INFO - Backtest progress: 1700/49000 bars (3.5%)
# 2025-11-14 17:49:59,631 - INFO - Signal detected: Price=$31567.89, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,643 - INFO - Signal detected: Price=$30498.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,647 - INFO - Signal detected: Price=$30647.50, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,750 - INFO - Signal detected: Price=$30597.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,770 - INFO - Signal detected: Price=$30083.53, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,773 - INFO - Backtest progress: 1800/49000 bars (3.7%)
# 2025-11-14 17:49:59,807 - INFO - Signal detected: Price=$31411.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,856 - INFO - Signal detected: Price=$30499.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,867 - INFO - Signal detected: Price=$30137.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,874 - INFO - Signal detected: Price=$30302.30, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,881 - INFO - Signal detected: Price=$30260.74, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,906 - INFO - Signal detected: Price=$30920.00, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:49:59,924 - INFO - Backtest progress: 1900/49000 bars (3.9%)
# 2025-11-14 17:49:59,944 - INFO - Signal detected: Price=$31400.24, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,956 - INFO - Signal detected: Price=$31290.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:49:59,972 - INFO - Signal detected: Price=$31313.41, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,049 - INFO - Signal detected: Price=$31196.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,066 - INFO - Signal detected: Price=$31239.22, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,081 - INFO - Signal detected: Price=$34309.75, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:00,082 - INFO - Backtest progress: 2000/49000 bars (4.1%)
# 2025-11-14 17:50:00,112 - INFO - Signal detected: Price=$33997.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,116 - INFO - Signal detected: Price=$34234.09, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,159 - INFO - Signal detected: Price=$34062.57, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,162 - INFO - Signal detected: Price=$34053.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,250 - INFO - Backtest progress: 2100/49000 bars (4.3%)
# 2025-11-14 17:50:00,264 - INFO - Signal detected: Price=$33748.27, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:00,283 - INFO - Signal detected: Price=$33486.11, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,308 - INFO - Signal detected: Price=$33551.80, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:00,316 - INFO - Signal detected: Price=$33452.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,323 - INFO - Signal detected: Price=$33579.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,364 - INFO - Signal detected: Price=$33452.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,402 - INFO - Backtest progress: 2200/49000 bars (4.5%)
# 2025-11-14 17:50:00,418 - INFO - Signal detected: Price=$32811.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,523 - INFO - Signal detected: Price=$33158.84, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,541 - INFO - Signal detected: Price=$32873.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,558 - INFO - Backtest progress: 2300/49000 bars (4.7%)
# 2025-11-14 17:50:00,599 - INFO - Signal detected: Price=$33580.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,630 - INFO - Signal detected: Price=$33621.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,668 - INFO - Signal detected: Price=$33474.82, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,681 - INFO - Signal detected: Price=$33765.55, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,699 - INFO - Signal detected: Price=$33800.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,712 - INFO - Backtest progress: 2400/49000 bars (4.9%)
# 2025-11-14 17:50:00,747 - INFO - Signal detected: Price=$34139.13, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,805 - INFO - Signal detected: Price=$33722.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,808 - INFO - Signal detected: Price=$33770.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,861 - INFO - Signal detected: Price=$33483.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,881 - INFO - Backtest progress: 2500/49000 bars (5.1%)
# 2025-11-14 17:50:00,924 - INFO - Signal detected: Price=$33940.49, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,967 - INFO - Signal detected: Price=$33685.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,970 - INFO - Signal detected: Price=$33702.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:00,996 - INFO - Signal detected: Price=$33525.90, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:01,055 - INFO - Backtest progress: 2600/49000 bars (5.3%)
# 2025-11-14 17:50:01,161 - INFO - Signal detected: Price=$34237.66, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,183 - INFO - Signal detected: Price=$34350.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,220 - INFO - Backtest progress: 2700/49000 bars (5.5%)
# 2025-11-14 17:50:01,237 - INFO - Signal detected: Price=$35151.32, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,273 - INFO - Signal detected: Price=$35220.18, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:01,291 - INFO - Signal detected: Price=$34709.50, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,304 - INFO - Signal detected: Price=$34737.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,308 - INFO - Signal detected: Price=$34865.38, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,313 - INFO - Signal detected: Price=$34759.93, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,366 - INFO - Backtest progress: 2800/49000 bars (5.7%)
# 2025-11-14 17:50:01,393 - INFO - Signal detected: Price=$35677.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,423 - INFO - Signal detected: Price=$35793.74, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,529 - INFO - Backtest progress: 2900/49000 bars (5.9%)
# 2025-11-14 17:50:01,657 - INFO - Signal detected: Price=$35899.97, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,681 - INFO - Signal detected: Price=$48661.18, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:01,681 - INFO - Backtest progress: 3000/49000 bars (6.1%)
# 2025-11-14 17:50:01,687 - INFO - Signal detected: Price=$47781.78, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:01,758 - INFO - Signal detected: Price=$51005.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,760 - INFO - Signal detected: Price=$51005.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,784 - INFO - Signal detected: Price=$50258.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,789 - INFO - Signal detected: Price=$50497.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,791 - INFO - Signal detected: Price=$50502.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,794 - INFO - Signal detected: Price=$49773.22, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,813 - INFO - Signal detected: Price=$49927.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,830 - INFO - Backtest progress: 3100/49000 bars (6.3%)
# 2025-11-14 17:50:01,846 - INFO - Signal detected: Price=$50918.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,913 - INFO - Signal detected: Price=$50927.20, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,941 - INFO - Signal detected: Price=$49405.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,965 - INFO - Signal detected: Price=$49180.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:01,989 - INFO - Backtest progress: 3200/49000 bars (6.5%)
# 2025-11-14 17:50:02,104 - INFO - Signal detected: Price=$48790.70, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,148 - INFO - Signal detected: Price=$50151.40, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,160 - INFO - Backtest progress: 3300/49000 bars (6.7%)
# 2025-11-14 17:50:02,180 - INFO - Signal detected: Price=$50774.51, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,186 - INFO - Signal detected: Price=$50610.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,261 - INFO - Signal detected: Price=$50440.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,284 - INFO - Signal detected: Price=$50508.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,320 - INFO - Backtest progress: 3400/49000 bars (6.9%)
# 2025-11-14 17:50:02,355 - INFO - Signal detected: Price=$49643.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,392 - INFO - Signal detected: Price=$51483.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,406 - INFO - Signal detected: Price=$51408.98, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,430 - INFO - Signal detected: Price=$50940.72, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,467 - INFO - Backtest progress: 3500/49000 bars (7.1%)
# 2025-11-14 17:50:02,521 - INFO - Signal detected: Price=$48733.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,550 - INFO - Signal detected: Price=$48039.27, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,627 - INFO - Backtest progress: 3600/49000 bars (7.3%)
# 2025-11-14 17:50:02,630 - INFO - Signal detected: Price=$46605.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,740 - INFO - Signal detected: Price=$45283.50, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:02,784 - INFO - Backtest progress: 3700/49000 bars (7.6%)
# 2025-11-14 17:50:02,795 - INFO - Signal detected: Price=$46696.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,800 - INFO - Signal detected: Price=$46406.15, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,812 - INFO - Signal detected: Price=$46343.40, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,848 - INFO - Signal detected: Price=$45918.69, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,878 - INFO - Signal detected: Price=$47478.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,929 - INFO - Backtest progress: 3800/49000 bars (7.8%)
# 2025-11-14 17:50:02,950 - INFO - Signal detected: Price=$47028.98, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,971 - INFO - Signal detected: Price=$46288.05, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,994 - INFO - Signal detected: Price=$45706.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:02,997 - INFO - Signal detected: Price=$45718.18, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,014 - INFO - Signal detected: Price=$46065.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,078 - INFO - Signal detected: Price=$47920.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,088 - INFO - Backtest progress: 3900/49000 bars (8.0%)
# 2025-11-14 17:50:03,104 - INFO - Signal detected: Price=$47418.60, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,106 - INFO - Signal detected: Price=$47650.90, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,136 - INFO - Signal detected: Price=$47711.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,153 - INFO - Signal detected: Price=$48297.47, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:03,167 - INFO - Signal detected: Price=$47121.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,182 - INFO - Signal detected: Price=$47030.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,185 - INFO - Signal detected: Price=$46721.24, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:03,200 - INFO - Signal detected: Price=$46736.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,231 - INFO - Signal detected: Price=$46798.86, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,238 - INFO - Signal detected: Price=$47083.25, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,240 - INFO - Signal detected: Price=$49830.75, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:03,241 - INFO - Backtest progress: 4000/49000 bars (8.2%)
# 2025-11-14 17:50:03,263 - INFO - Signal detected: Price=$48991.43, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:03,277 - INFO - Signal detected: Price=$49334.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,338 - INFO - Signal detected: Price=$49383.14, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,343 - INFO - Signal detected: Price=$48941.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,359 - INFO - Signal detected: Price=$48653.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,398 - INFO - Backtest progress: 4100/49000 bars (8.4%)
# 2025-11-14 17:50:03,411 - INFO - Signal detected: Price=$48896.27, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,428 - INFO - Signal detected: Price=$49135.40, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,452 - INFO - Signal detected: Price=$48784.78, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:03,473 - INFO - Signal detected: Price=$49120.65, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,511 - INFO - Signal detected: Price=$49101.70, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,556 - INFO - Signal detected: Price=$48620.92, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,561 - INFO - Signal detected: Price=$47930.38, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:03,564 - INFO - Backtest progress: 4200/49000 bars (8.6%)
# 2025-11-14 17:50:03,680 - INFO - Signal detected: Price=$47633.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,700 - INFO - Signal detected: Price=$48500.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,717 - INFO - Signal detected: Price=$48550.13, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,721 - INFO - Signal detected: Price=$48707.56, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,726 - INFO - Backtest progress: 4300/49000 bars (8.8%)
# 2025-11-14 17:50:03,755 - INFO - Signal detected: Price=$48638.50, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,757 - INFO - Signal detected: Price=$48647.84, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,777 - INFO - Signal detected: Price=$48682.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,805 - INFO - Signal detected: Price=$49119.38, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,808 - INFO - Signal detected: Price=$49110.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,837 - INFO - Signal detected: Price=$49826.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,846 - INFO - Signal detected: Price=$49795.17, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,849 - INFO - Signal detected: Price=$49772.14, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,873 - INFO - Backtest progress: 4400/49000 bars (9.0%)
# 2025-11-14 17:50:03,900 - INFO - Signal detected: Price=$51438.34, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,927 - INFO - Signal detected: Price=$51683.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,941 - INFO - Signal detected: Price=$52274.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,955 - INFO - Signal detected: Price=$51576.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,959 - INFO - Signal detected: Price=$51310.01, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:03,981 - INFO - Signal detected: Price=$50895.79, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,001 - INFO - Signal detected: Price=$51187.95, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,021 - INFO - Backtest progress: 4500/49000 bars (9.2%)
# 2025-11-14 17:50:04,064 - INFO - Signal detected: Price=$50981.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,132 - INFO - Signal detected: Price=$50785.78, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,194 - INFO - Backtest progress: 4600/49000 bars (9.4%)
# 2025-11-14 17:50:04,200 - INFO - Signal detected: Price=$51514.12, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,232 - INFO - Signal detected: Price=$49779.60, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,322 - INFO - Signal detected: Price=$49069.95, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,326 - INFO - Signal detected: Price=$48883.43, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,330 - INFO - Signal detected: Price=$49070.27, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,338 - INFO - Backtest progress: 4700/49000 bars (9.6%)
# 2025-11-14 17:50:04,358 - INFO - Signal detected: Price=$49285.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,374 - INFO - Signal detected: Price=$49456.46, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,452 - INFO - Signal detected: Price=$49923.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,493 - INFO - Backtest progress: 4800/49000 bars (9.8%)
# 2025-11-14 17:50:04,510 - INFO - Signal detected: Price=$48200.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,515 - INFO - Signal detected: Price=$47945.61, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,522 - INFO - Signal detected: Price=$48015.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,536 - INFO - Signal detected: Price=$48008.22, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,557 - INFO - Signal detected: Price=$48151.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,566 - INFO - Signal detected: Price=$48162.43, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,582 - INFO - Signal detected: Price=$48459.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,641 - INFO - Backtest progress: 4900/49000 bars (10.0%)
# 2025-11-14 17:50:04,743 - INFO - Signal detected: Price=$47109.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,805 - INFO - Signal detected: Price=$51881.06, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:04,806 - INFO - Backtest progress: 5000/49000 bars (10.2%)
# 2025-11-14 17:50:04,831 - INFO - Signal detected: Price=$52308.29, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,855 - INFO - Signal detected: Price=$51783.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,884 - INFO - Signal detected: Price=$52375.36, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:04,949 - INFO - Backtest progress: 5100/49000 bars (10.4%)
# 2025-11-14 17:50:04,985 - INFO - Signal detected: Price=$53247.57, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,010 - INFO - Signal detected: Price=$52879.14, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,012 - INFO - Signal detected: Price=$52938.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,021 - INFO - Signal detected: Price=$53022.33, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,049 - INFO - Signal detected: Price=$53228.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,091 - INFO - Signal detected: Price=$53290.85, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,097 - INFO - Signal detected: Price=$53430.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,109 - INFO - Backtest progress: 5200/49000 bars (10.6%)
# 2025-11-14 17:50:05,139 - INFO - Signal detected: Price=$53797.67, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,153 - INFO - Signal detected: Price=$53710.66, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,155 - INFO - Signal detected: Price=$53707.60, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,192 - INFO - Signal detected: Price=$54144.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,269 - INFO - Backtest progress: 5300/49000 bars (10.8%)
# 2025-11-14 17:50:05,277 - INFO - Signal detected: Price=$54800.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,288 - INFO - Signal detected: Price=$54643.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,302 - INFO - Signal detected: Price=$54681.45, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,408 - INFO - Signal detected: Price=$54926.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,430 - INFO - Signal detected: Price=$54898.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,435 - INFO - Backtest progress: 5400/49000 bars (11.0%)
# 2025-11-14 17:50:05,502 - INFO - Signal detected: Price=$54290.90, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,520 - INFO - Signal detected: Price=$54595.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,545 - INFO - Signal detected: Price=$55024.13, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:05,592 - INFO - Backtest progress: 5500/49000 bars (11.2%)
# 2025-11-14 17:50:05,612 - INFO - Signal detected: Price=$55855.64, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,616 - INFO - Signal detected: Price=$55729.55, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,665 - INFO - Signal detected: Price=$55807.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,703 - INFO - Signal detected: Price=$56184.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,706 - INFO - Signal detected: Price=$56281.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,752 - INFO - Signal detected: Price=$55912.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,768 - INFO - Backtest progress: 5600/49000 bars (11.4%)
# 2025-11-14 17:50:05,813 - INFO - Signal detected: Price=$56298.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,816 - INFO - Signal detected: Price=$56217.23, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,824 - INFO - Signal detected: Price=$56151.44, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,829 - INFO - Signal detected: Price=$56303.15, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,888 - INFO - Signal detected: Price=$56131.08, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,930 - INFO - Backtest progress: 5700/49000 bars (11.6%)
# 2025-11-14 17:50:05,937 - INFO - Signal detected: Price=$55951.59, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,945 - INFO - Signal detected: Price=$55966.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,965 - INFO - Signal detected: Price=$55922.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,969 - INFO - Signal detected: Price=$55666.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:05,980 - INFO - Signal detected: Price=$55574.93, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:06,011 - INFO - Signal detected: Price=$55683.77, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# ...
# 2025-11-14 17:50:09,910 - INFO - Signal detected: Price=$57505.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:09,952 - INFO - Signal detected: Price=$57820.40, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:09,976 - INFO - Signal detected: Price=$57575.65, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:09,999 - INFO - Signal detected: Price=$57640.04, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,019 - INFO - Signal detected: Price=$57876.96, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,039 - INFO - Signal detected: Price=$57344.89, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,040 - INFO - Backtest progress: 8300/49000 bars (16.9%)
# 2025-11-14 17:50:10,050 - INFO - Signal detected: Price=$57342.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,148 - INFO - Signal detected: Price=$57608.76, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,208 - INFO - Signal detected: Price=$57042.25, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,293 - INFO - Backtest progress: 8400/49000 bars (17.1%)
# 2025-11-14 17:50:10,338 - INFO - Signal detected: Price=$57120.05, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:10,358 - INFO - Signal detected: Price=$56864.16, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,377 - INFO - Signal detected: Price=$56714.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,413 - INFO - Signal detected: Price=$56653.33, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,427 - INFO - Signal detected: Price=$56729.46, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,432 - INFO - Signal detected: Price=$56552.41, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:10,436 - INFO - Signal detected: Price=$56741.91, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,448 - INFO - Signal detected: Price=$56637.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,457 - INFO - Backtest progress: 8500/49000 bars (17.3%)
# 2025-11-14 17:50:10,487 - INFO - Signal detected: Price=$56770.66, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,518 - INFO - Signal detected: Price=$57033.52, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:10,523 - INFO - Signal detected: Price=$56950.79, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,563 - INFO - Signal detected: Price=$56399.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,567 - INFO - Signal detected: Price=$56538.63, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,619 - INFO - Backtest progress: 8600/49000 bars (17.6%)
# 2025-11-14 17:50:10,716 - INFO - Signal detected: Price=$57992.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,760 - INFO - Signal detected: Price=$58750.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,766 - INFO - Signal detected: Price=$58721.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,795 - INFO - Backtest progress: 8700/49000 bars (17.8%)
# 2025-11-14 17:50:10,805 - INFO - Signal detected: Price=$58494.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,855 - INFO - Signal detected: Price=$58647.48, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,881 - INFO - Signal detected: Price=$57885.35, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,910 - INFO - Signal detected: Price=$57545.76, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,932 - INFO - Signal detected: Price=$57851.19, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:10,957 - INFO - Backtest progress: 8800/49000 bars (18.0%)
# 2025-11-14 17:50:10,981 - INFO - Signal detected: Price=$57580.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,022 - INFO - Signal detected: Price=$56967.43, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,120 - INFO - Backtest progress: 8900/49000 bars (18.2%)
# 2025-11-14 17:50:11,152 - INFO - Signal detected: Price=$55839.90, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,184 - INFO - Signal detected: Price=$56110.06, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,190 - INFO - Signal detected: Price=$56113.44, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,196 - INFO - Signal detected: Price=$56131.11, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,199 - INFO - Signal detected: Price=$56260.90, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,287 - INFO - Signal detected: Price=$39014.45, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:11,289 - INFO - Backtest progress: 9000/49000 bars (18.4%)
# 2025-11-14 17:50:11,396 - INFO - Signal detected: Price=$38066.30, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,407 - INFO - Signal detected: Price=$38192.97, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,429 - INFO - Signal detected: Price=$38970.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,443 - INFO - Signal detected: Price=$38760.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,448 - INFO - Backtest progress: 9100/49000 bars (18.6%)
# 2025-11-14 17:50:11,480 - INFO - Signal detected: Price=$37438.21, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:11,494 - INFO - Signal detected: Price=$37139.55, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,527 - INFO - Signal detected: Price=$37037.75, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,539 - INFO - Signal detected: Price=$37395.14, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,552 - INFO - Signal detected: Price=$37766.50, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,578 - INFO - Signal detected: Price=$38304.11, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,580 - INFO - Signal detected: Price=$38176.18, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,598 - INFO - Backtest progress: 9200/49000 bars (18.8%)
# 2025-11-14 17:50:11,614 - INFO - Signal detected: Price=$37807.79, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,622 - INFO - Signal detected: Price=$37900.27, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,649 - INFO - Signal detected: Price=$37813.29, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,653 - INFO - Signal detected: Price=$37630.49, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,685 - INFO - Signal detected: Price=$37685.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,740 - INFO - Signal detected: Price=$38202.42, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,759 - INFO - Backtest progress: 9300/49000 bars (19.0%)
# 2025-11-14 17:50:11,812 - INFO - Signal detected: Price=$39417.24, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,825 - INFO - Signal detected: Price=$39328.36, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:11,916 - INFO - Backtest progress: 9400/49000 bars (19.2%)
# 2025-11-14 17:50:11,966 - INFO - Signal detected: Price=$39901.53, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,039 - INFO - Signal detected: Price=$39166.66, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,061 - INFO - Signal detected: Price=$38462.48, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,070 - INFO - Backtest progress: 9500/49000 bars (19.4%)
# 2025-11-14 17:50:12,077 - INFO - Signal detected: Price=$39036.66, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,108 - INFO - Signal detected: Price=$38344.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,130 - INFO - Signal detected: Price=$38666.72, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,166 - INFO - Signal detected: Price=$39133.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,253 - INFO - Backtest progress: 9600/49000 bars (19.6%)
# 2025-11-14 17:50:12,257 - INFO - Signal detected: Price=$37826.86, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,283 - INFO - Signal detected: Price=$37502.73, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,379 - INFO - Signal detected: Price=$38277.78, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,415 - INFO - Signal detected: Price=$39180.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,430 - INFO - Backtest progress: 9700/49000 bars (19.8%)
# 2025-11-14 17:50:12,461 - INFO - Signal detected: Price=$39550.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,471 - INFO - Signal detected: Price=$39590.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,473 - INFO - Signal detected: Price=$39351.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,530 - INFO - Signal detected: Price=$39810.71, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,581 - INFO - Backtest progress: 9800/49000 bars (20.0%)
# 2025-11-14 17:50:12,653 - INFO - Signal detected: Price=$38808.04, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,738 - INFO - Signal detected: Price=$38307.24, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,745 - INFO - Backtest progress: 9900/49000 bars (20.2%)
# 2025-11-14 17:50:12,765 - INFO - Signal detected: Price=$38035.36, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,771 - INFO - Signal detected: Price=$38282.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,847 - INFO - Signal detected: Price=$37002.71, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:12,931 - INFO - Backtest progress: 10000/49000 bars (20.4%)
# 2025-11-14 17:50:13,019 - INFO - Signal detected: Price=$34677.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,023 - INFO - Signal detected: Price=$34328.90, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,043 - INFO - Signal detected: Price=$34542.65, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 17:50:13,107 - INFO - Backtest progress: 10100/49000 bars (20.6%)
# 2025-11-14 17:50:13,114 - INFO - Signal detected: Price=$36075.86, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,129 - INFO - Signal detected: Price=$36154.90, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,174 - INFO - Signal detected: Price=$36904.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,210 - INFO - Signal detected: Price=$36959.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,268 - INFO - Backtest progress: 10200/49000 bars (20.8%)
# 2025-11-14 17:50:13,312 - INFO - Signal detected: Price=$36698.75, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,355 - INFO - Signal detected: Price=$36748.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,361 - INFO - Signal detected: Price=$36796.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,388 - INFO - Signal detected: Price=$37005.71, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,406 - INFO - Signal detected: Price=$37544.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,412 - INFO - Signal detected: Price=$37751.89, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,423 - INFO - Backtest progress: 10300/49000 bars (21.0%)
# 2025-11-14 17:50:13,457 - INFO - Signal detected: Price=$36862.50, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,468 - INFO - Signal detected: Price=$36879.29, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,471 - INFO - Signal detected: Price=$36580.02, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 17:50:13,483 - INFO - Signal detected: Price=$36665.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,501 - INFO - Signal detected: Price=$36871.39, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,504 - INFO - Signal detected: Price=$36902.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,569 - INFO - Signal detected: Price=$36603.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,591 - INFO - Backtest progress: 10400/49000 bars (21.2%)
# 2025-11-14 17:50:13,596 - INFO - Signal detected: Price=$36195.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,605 - INFO - Signal detected: Price=$36320.51, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,616 - INFO - Signal detected: Price=$36493.86, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,723 - INFO - Signal detected: Price=$36139.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 17:50:13,750 - INFO - Backtest progress: 10500/49000 bars (21.4%)

# %%
"""
BTC Backtesting Script with Historical Data Collection
Collects BTC historical data from Alpaca, stores in TimescaleDB, and runs backtests
"""

import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import pytz
import logging
import sys
import os
from typing import Optional, Dict, Any
import warnings

# Suppress pandas SettingWithCopyWarning - we handle copying explicitly
pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# Modern Alpaca imports
from alpaca.trading.client import TradingClient
from alpaca.data.historical.crypto import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit

# Observability imports
from prometheus_client import Counter, Gauge, start_http_server, REGISTRY
import json
import requests

# Loki logging
from pythonjsonlogger import jsonlogger

# Database (TimescaleDB)
import psycopg2
from psycopg2.pool import SimpleConnectionPool

# MLflow
import mlflow

# Configure logging
class LokiHandler(logging.Handler):
    """Custom handler to send logs to Loki"""
    def __init__(self, loki_url, labels=None):
        super().__init__()
        self.loki_url = loki_url
        self.labels = labels or {}
        self.session = requests.Session()
        
    def emit(self, record):
        try:
            log_entry = {
                "streams": [{
                    "stream": {
                        "job": "btc_backtest",
                        "level": record.levelname.lower(),
                        **self.labels
                    },
                    "values": [[
                        str(int(record.created * 1e9)),
                        json.dumps({
                            "message": self.format(record),
                            "level": record.levelname,
                            "logger": record.name
                        })
                    ]]
                }]
            }
            response = self.session.post(self.loki_url, json=log_entry, timeout=5)
            response.raise_for_status()
        except Exception:
            pass

def setup_logging(level=logging.INFO, loki_url=None, loki_labels=None):
    """Setup logging"""
    logger = logging.getLogger()
    logger.setLevel(level)
    logger.handlers.clear()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    
    stream_handler = logging.StreamHandler(sys.stdout)
    stream_handler.setFormatter(formatter)
    logger.addHandler(stream_handler)
    
    if loki_url:
        try:
            loki_handler = LokiHandler(loki_url, loki_labels)
            loki_handler.setFormatter(formatter)
            logger.addHandler(loki_handler)
        except Exception:
            pass
    
    return logger

logger = setup_logging()

# Database connection pool for TimescaleDB
class TimescaleDB:
    """TimescaleDB connection and operations"""
    def __init__(self, connection_string=None):
        self.connection_string = connection_string
        self.pool = None
        if connection_string:
            try:
                self.pool = SimpleConnectionPool(1, 10, connection_string)
                self._init_schema()
                logger.info("TimescaleDB connection pool created")
            except Exception as e:
                logger.error(f"Failed to connect to TimescaleDB: {e}")
    
    def _init_schema(self):
        """Initialize database schema"""
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            
            # Create trades table
            cur.execute("""
                CREATE TABLE IF NOT EXISTS trades (
                    id SERIAL PRIMARY KEY,
                    timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                    symbol VARCHAR(50) NOT NULL,
                    direction VARCHAR(10) NOT NULL,
                    quantity DECIMAL(18, 8) NOT NULL,
                    entry_price DECIMAL(18, 2) NOT NULL,
                    stop_loss DECIMAL(18, 2),
                    take_profit DECIMAL(18, 2),
                    atr_value DECIMAL(18, 2),
                    status VARCHAR(20) DEFAULT 'open',
                    exit_price DECIMAL(18, 2),
                    exit_timestamp TIMESTAMPTZ,
                    pnl DECIMAL(18, 2),
                    daily_trade_number INTEGER,
                    mlflow_run_id VARCHAR(255)
                );
            """)
            
            # Create backtest_results table for storing metrics
            cur.execute("""
                CREATE TABLE IF NOT EXISTS backtest_results (
                    id SERIAL PRIMARY KEY,
                    timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                    start_date DATE NOT NULL,
                    end_date DATE NOT NULL,
                    symbol VARCHAR(50) NOT NULL,
                    timeframe VARCHAR(10) NOT NULL,
                    total_trades INTEGER,
                    winning_trades INTEGER,
                    losing_trades INTEGER,
                    win_rate DECIMAL(5, 4),
                    total_return_pct DECIMAL(10, 4),
                    roi DECIMAL(10, 4),
                    sharpe_ratio DECIMAL(10, 4),
                    max_drawdown_pct DECIMAL(10, 4),
                    profit_factor DECIMAL(10, 4),
                    avg_win_pct DECIMAL(10, 4),
                    avg_loss_pct DECIMAL(10, 4),
                    initial_capital DECIMAL(18, 2),
                    final_equity DECIMAL(18, 2),
                    net_profit DECIMAL(18, 2),
                    mlflow_run_id VARCHAR(255)
                );
            """)
            
            try:
                cur.execute("SELECT create_hypertable('trades', 'timestamp', if_not_exists => TRUE);")
                cur.execute("SELECT create_hypertable('backtest_results', 'timestamp', if_not_exists => TRUE);")
            except Exception:
                logger.warning("Could not create hypertable (may be regular PostgreSQL)")
            
            # Create index for backtest_results
            cur.execute("""
                CREATE INDEX IF NOT EXISTS idx_backtest_results_symbol_date 
                ON backtest_results (symbol, start_date, end_date);
            """)
            
            conn.commit()
            
            # Verify tables were created
            cur.execute("""
                SELECT table_name 
                FROM information_schema.tables 
                WHERE table_schema = 'public' 
                AND table_name IN ('trades', 'backtest_results');
            """)
            created_tables = [row[0] for row in cur.fetchall()]
            
            if 'trades' not in created_tables:
                logger.error("⚠️  WARNING: 'trades' table was not created!")
            if 'backtest_results' not in created_tables:
                logger.error("⚠️  WARNING: 'backtest_results' table was not created!")
            
            logger.info(f"TimescaleDB schema initialized. Tables: {created_tables}")
        except Exception as e:
            conn.rollback()
            logger.error(f"❌ Schema initialization error: {e}", exc_info=True)
            # Try to create tables individually with better error handling
            try:
                cur2 = conn.cursor()
                cur2.execute("""
                    CREATE TABLE IF NOT EXISTS trades (
                        id SERIAL PRIMARY KEY,
                        timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                        symbol VARCHAR(50) NOT NULL,
                        direction VARCHAR(10) NOT NULL,
                        quantity DECIMAL(18, 8) NOT NULL,
                        entry_price DECIMAL(18, 2) NOT NULL,
                        stop_loss DECIMAL(18, 2),
                        take_profit DECIMAL(18, 2),
                        atr_value DECIMAL(18, 2),
                        status VARCHAR(20) DEFAULT 'open',
                        exit_price DECIMAL(18, 2),
                        exit_timestamp TIMESTAMPTZ,
                        pnl DECIMAL(18, 2),
                        daily_trade_number INTEGER,
                        mlflow_run_id VARCHAR(255)
                    );
                """)
                conn.commit()
                cur2.close()
                logger.info("✓ Trades table created successfully (fallback)")
            except Exception as e2:
                logger.error(f"Failed to create trades table (fallback): {e2}", exc_info=True)
        finally:
            self.pool.putconn(conn)
    
    def insert_backtest_results(self, metrics_data):
        """Insert backtest metrics into database"""
        if not self.pool:
            return None
        
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            cur.execute("""
                INSERT INTO backtest_results (
                    start_date, end_date, symbol, timeframe,
                    total_trades, winning_trades, losing_trades, win_rate,
                    total_return_pct, roi, sharpe_ratio, max_drawdown_pct,
                    profit_factor, avg_win_pct, avg_loss_pct,
                    initial_capital, final_equity, net_profit, mlflow_run_id
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                RETURNING id;
            """, (
                metrics_data.get('start_date'),
                metrics_data.get('end_date'),
                metrics_data.get('symbol'),
                metrics_data.get('timeframe'),
                metrics_data.get('total_trades'),
                metrics_data.get('winning_trades'),
                metrics_data.get('losing_trades'),
                metrics_data.get('win_rate'),
                metrics_data.get('total_return_pct'),
                metrics_data.get('roi'),
                metrics_data.get('sharpe_ratio'),
                metrics_data.get('max_drawdown_pct'),
                metrics_data.get('profit_factor'),
                metrics_data.get('avg_win_pct'),
                metrics_data.get('avg_loss_pct'),
                metrics_data.get('initial_capital'),
                metrics_data.get('final_equity'),
                metrics_data.get('net_profit'),
                metrics_data.get('mlflow_run_id')
            ))
            result_id = cur.fetchone()[0]
            conn.commit()
            logger.info(f"✓ Backtest results inserted successfully with ID: {result_id}")
            sharpe = metrics_data.get('sharpe_ratio', 0) or 0
            roi = metrics_data.get('roi', 0) or 0
            logger.info(f"  Metrics: Trades={metrics_data.get('total_trades', 0)}, "
                       f"Sharpe={sharpe:.4f}, "
                       f"ROI={roi:.2f}%")
            return result_id
        except Exception as e:
            conn.rollback()
            logger.error(f"Error inserting backtest results: {e}", exc_info=True)
            return None
        finally:
            self.pool.putconn(conn)
    
    def insert_trade(self, trade_data):
        """Insert a trade record"""
        if not self.pool:
            logger.warning("No database pool available, skipping trade insertion")
            return None
        
        conn = self.pool.getconn()
        try:
            cur = conn.cursor()
            
            # Verify trades table exists
            cur.execute("""
                SELECT EXISTS (
                    SELECT FROM information_schema.tables 
                    WHERE table_schema = 'public' 
                    AND table_name = 'trades'
                );
            """)
            table_exists = cur.fetchone()[0]
            
            if not table_exists:
                logger.error("❌ 'trades' table does not exist! Creating it now...")
                cur.execute("""
                    CREATE TABLE IF NOT EXISTS trades (
                        id SERIAL PRIMARY KEY,
                        timestamp TIMESTAMPTZ NOT NULL DEFAULT NOW(),
                        symbol VARCHAR(50) NOT NULL,
                        direction VARCHAR(10) NOT NULL,
                        quantity DECIMAL(18, 8) NOT NULL,
                        entry_price DECIMAL(18, 2) NOT NULL,
                        stop_loss DECIMAL(18, 2),
                        take_profit DECIMAL(18, 2),
                        atr_value DECIMAL(18, 2),
                        status VARCHAR(20) DEFAULT 'open',
                        exit_price DECIMAL(18, 2),
                        exit_timestamp TIMESTAMPTZ,
                        pnl DECIMAL(18, 2),
                        daily_trade_number INTEGER,
                        mlflow_run_id VARCHAR(255)
                    );
                """)
                conn.commit()
                logger.info("✓ Trades table created")
            
            cur.execute("""
                INSERT INTO trades (
                    symbol, direction, quantity, entry_price, stop_loss, 
                    take_profit, atr_value, daily_trade_number, mlflow_run_id
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
                RETURNING id;
            """, (
                trade_data.get('symbol'),
                trade_data.get('direction'),
                trade_data.get('quantity'),
                trade_data.get('entry_price'),
                trade_data.get('stop_loss'),
                trade_data.get('take_profit'),
                trade_data.get('atr_value'),
                trade_data.get('daily_trade_number'),
                trade_data.get('mlflow_run_id')
            ))
            trade_id = cur.fetchone()[0]
            conn.commit()
            return trade_id
        except Exception as e:
            conn.rollback()
            logger.error(f"Error inserting trade: {e}", exc_info=True)
            return None
        finally:
            self.pool.putconn(conn)

# Historical Data Collector
class HistoricalDataCollector:
    """Collect and store historical BTC data in TimescaleDB"""
    
    def __init__(self, db: TimescaleDB, api_key: str, api_secret: str):
        self.db = db
        self.data_client = CryptoHistoricalDataClient(api_key, api_secret)
        self._create_ohlcv_table()
    
    def _create_ohlcv_table(self):
        """Create OHLCV table in TimescaleDB"""
        conn = self.db.pool.getconn()
        try:
            cur = conn.cursor()
            cur.execute("""
                CREATE TABLE IF NOT EXISTS ohlcv_data (
                    timestamp TIMESTAMPTZ NOT NULL,
                    symbol VARCHAR(20) NOT NULL,
                    timeframe VARCHAR(10) NOT NULL,
                    open DECIMAL(20, 8),
                    high DECIMAL(20, 8),
                    low DECIMAL(20, 8),
                    close DECIMAL(20, 8),
                    volume DECIMAL(30, 8),
                    PRIMARY KEY (timestamp, symbol, timeframe)
                );
            """)
            
            try:
                cur.execute("SELECT create_hypertable('ohlcv_data', 'timestamp', if_not_exists => TRUE);")
            except Exception:
                logger.warning("Could not create hypertable for ohlcv_data")
            
            cur.execute("""
                CREATE INDEX IF NOT EXISTS idx_ohlcv_symbol_timeframe 
                ON ohlcv_data (symbol, timeframe, timestamp DESC);
            """)
            
            conn.commit()
            logger.info("OHLCV table created/verified")
        except Exception as e:
            conn.rollback()
            logger.error(f"Error creating OHLCV table: {e}")
        finally:
            self.db.pool.putconn(conn)
    
    def _normalize_symbol(self, symbol: str) -> str:
        """Normalize symbol format (BTC/USD -> BTCUSD)"""
        # Convert BTC/USD format to BTCUSD
        return symbol.replace('/', '').replace('-', '').upper()
    
    def collect_historical_data(self, symbol: str, start_date: str, end_date: str, 
                               timeframe: str = '5Min'):
        """Collect historical data from Alpaca and store in TimescaleDB"""
        timeframe_map = {
            '1Min': TimeFrame(1, TimeFrameUnit.Minute),
            '5Min': TimeFrame(5, TimeFrameUnit.Minute),
            '15Min': TimeFrame(15, TimeFrameUnit.Minute),
            '1Hour': TimeFrame(1, TimeFrameUnit.Hour),
            '1Day': TimeFrame(1, TimeFrameUnit.Day)
        }
        
        tf = timeframe_map.get(timeframe, TimeFrame(5, TimeFrameUnit.Minute))
        
        start_dt = datetime.strptime(start_date, '%Y-%m-%d').replace(tzinfo=pytz.UTC)
        end_dt = datetime.strptime(end_date, '%Y-%m-%d').replace(tzinfo=pytz.UTC)
        
        # Normalize symbol for storage (BTC/USD -> BTCUSD)
        normalized_symbol = self._normalize_symbol(symbol)
        
        logger.info(f"Collecting {symbol} data from {start_date} to {end_date} ({timeframe})")
        logger.info(f"Storing as symbol: {normalized_symbol}")
        
        current_start = start_dt
        total_bars = 0
        
        while current_start < end_dt:
            chunk_end = min(current_start + timedelta(days=30), end_dt)
            
            try:
                request_params = CryptoBarsRequest(
                    symbol_or_symbols=[symbol],
                    timeframe=tf,
                    start=current_start,
                    end=chunk_end,
                    limit=1000
                )
                
                barset = self.data_client.get_crypto_bars(request_params)
                
                # Check what symbols Alpaca actually returned
                if barset and barset.data:
                    actual_symbols = list(barset.data.keys())
                    logger.debug(f"Alpaca returned symbols: {actual_symbols}")
                    # Use the first symbol returned by Alpaca if our symbol isn't found
                    if symbol not in barset.data:
                        if actual_symbols:
                            symbol_to_use = actual_symbols[0]
                            logger.info(f"Using symbol from Alpaca response: {symbol_to_use}")
                        else:
                            logger.warning(f"No data for {symbol} from {current_start} to {chunk_end}")
                            current_start = chunk_end
                            continue
                    else:
                        symbol_to_use = symbol
                else:
                    logger.warning(f"No data for {symbol} from {current_start} to {chunk_end}")
                    current_start = chunk_end
                    continue
                
                df = barset.df.reset_index()
                df = df.rename(columns={
                    'open': 'open',
                    'high': 'high',
                    'low': 'low',
                    'close': 'close',
                    'volume': 'volume'
                })
                df = df.set_index('timestamp')
                
                # Store in database with normalized symbol
                conn = self.db.pool.getconn()
                try:
                    cur = conn.cursor()
                    for idx, row in df.iterrows():
                        cur.execute("""
                            INSERT INTO ohlcv_data 
                            (timestamp, symbol, timeframe, open, high, low, close, volume)
                            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                            ON CONFLICT (timestamp, symbol, timeframe) 
                            DO UPDATE SET
                                open = EXCLUDED.open,
                                high = EXCLUDED.high,
                                low = EXCLUDED.low,
                                close = EXCLUDED.close,
                                volume = EXCLUDED.volume;
                        """, (
                            idx, normalized_symbol, timeframe,
                            float(row['open']), float(row['high']),
                            float(row['low']), float(row['close']),
                            float(row['volume'])
                        ))
                    conn.commit()
                    total_bars += len(df)
                    logger.info(f"Stored {len(df)} bars. Total: {total_bars}")
                except Exception as e:
                    conn.rollback()
                    logger.error(f"Error storing data: {e}")
                finally:
                    self.db.pool.putconn(conn)
                
                current_start = chunk_end
                time.sleep(0.5)  # Rate limiting
                
            except Exception as e:
                logger.error(f"Error fetching data: {e}")
                time.sleep(5)
                continue
        
        logger.info(f"Collection complete! Total bars stored: {total_bars}")
        return total_bars
    
    def get_historical_data_from_db(self, symbol: str, start_date: str, 
                                    end_date: str, timeframe: str = '5Min') -> pd.DataFrame:
        """Retrieve historical data from TimescaleDB"""
        conn = self.db.pool.getconn()
        try:
            # First, check what symbols actually exist in the database
            cur = conn.cursor()
            cur.execute("SELECT DISTINCT symbol FROM ohlcv_data LIMIT 10;")
            existing_symbols = [row[0] for row in cur.fetchall()]
            logger.info(f"Symbols found in database: {existing_symbols}")
            logger.info(f"Looking for symbol: {symbol} (normalized: {self._normalize_symbol(symbol)})")
            
            # Also check what timeframes exist for debugging
            cur.execute("SELECT DISTINCT timeframe FROM ohlcv_data;")
            existing_timeframes = [row[0] for row in cur.fetchall()]
            logger.info(f"Timeframes found in database: {existing_timeframes}")
            
            # Try to find matching symbol (normalized or original format)
            normalized_symbol = self._normalize_symbol(symbol)
            symbol_to_use = None
            
            # Check if normalized symbol exists
            if normalized_symbol in existing_symbols:
                symbol_to_use = normalized_symbol
                logger.info(f"✓ Found exact match: Using normalized symbol '{symbol_to_use}'")
            # Check if original symbol exists
            elif symbol in existing_symbols:
                symbol_to_use = symbol
                logger.info(f"✓ Found exact match: Using original symbol format '{symbol_to_use}'")
            # Try to find any symbol that matches when normalized
            else:
                for db_symbol in existing_symbols:
                    db_normalized = self._normalize_symbol(db_symbol)
                    if db_normalized == normalized_symbol:
                        symbol_to_use = db_symbol
                        logger.info(f"✓ Found normalized match: '{symbol}' -> '{symbol_to_use}' (DB has '{db_symbol}', normalized to '{db_normalized}')")
                        break
            
            if symbol_to_use is None:
                logger.warning(f"✗ No matching symbol found for '{symbol}' (normalized: '{normalized_symbol}')")
                logger.warning(f"Available symbols in DB: {existing_symbols}")
                return None
            
            # Convert date strings to proper format for PostgreSQL
            # Use PostgreSQL's date casting for reliability
            try:
                # Parse dates and ensure they're timezone-aware
                start_dt = pd.to_datetime(start_date)
                if start_dt.tz is None:
                    start_dt = start_dt.tz_localize('UTC')
                else:
                    start_dt = start_dt.tz_convert('UTC')
                
                end_dt = pd.to_datetime(end_date)
                if end_dt.tz is None:
                    end_dt = end_dt.tz_localize('UTC')
                else:
                    end_dt = end_dt.tz_convert('UTC')
                
                # Add one day to end_date to include the entire end day
                end_dt = end_dt + pd.Timedelta(days=1)
            except Exception as e:
                logger.error(f"Error parsing dates: {e}")
                return None
            
            query = """
                SELECT timestamp, open, high, low, close, volume
                FROM ohlcv_data
                WHERE symbol = %s 
                AND timeframe = %s
                AND timestamp >= %s 
                AND timestamp < %s
                ORDER BY timestamp ASC;
            """
            logger.info(f"Executing query: symbol='{symbol_to_use}', timeframe='{timeframe}', start={start_dt}, end={end_dt}")
            cur.execute(query, (symbol_to_use, timeframe, start_dt, end_dt))
            rows = cur.fetchall()
            colnames = [desc[0] for desc in cur.description]
            cur.close()
            
            if len(rows) == 0:
                logger.warning(f"No data found for '{symbol_to_use}' from {start_date} to {end_date} with timeframe {timeframe}")
                # Debug: Check if data exists for this symbol at all
                try:
                    cur2 = conn.cursor()
                    cur2.execute("SELECT MIN(timestamp), MAX(timestamp), COUNT(*) FROM ohlcv_data WHERE symbol = %s AND timeframe = %s;", 
                                (symbol_to_use, timeframe))
                    debug_info = cur2.fetchone()
                    cur2.close()
                    if debug_info and debug_info[2] > 0:
                        logger.info(f"Debug: Symbol '{symbol_to_use}' has {debug_info[2]} total bars")
                        logger.info(f"Debug: Available date range: {debug_info[0]} to {debug_info[1]}")
                        logger.info(f"Debug: Requested date range: {start_dt} to {end_dt}")
                        # Check if there's any overlap
                        if debug_info[0] and debug_info[1]:
                            if end_dt < debug_info[0] or start_dt > debug_info[1]:
                                logger.warning(f"⚠️  Requested date range ({start_date} to {end_date}) does NOT overlap with available data ({debug_info[0]} to {debug_info[1]})")
                            else:
                                logger.info(f"✓ Date ranges overlap, but no data returned. This might be a timezone or date format issue.")
                    else:
                        logger.warning(f"Debug: No data found for symbol '{symbol_to_use}' with timeframe '{timeframe}' at all!")
                except Exception as debug_e:
                    logger.error(f"Error in debug query: {debug_e}")
                return None
            
            df = pd.DataFrame(rows, columns=colnames)
            df['timestamp'] = pd.to_datetime(df['timestamp'])
            
            # Convert Decimal columns to float (PostgreSQL DECIMAL returns as Decimal type)
            numeric_columns = ['open', 'high', 'low', 'close', 'volume']
            for col in numeric_columns:
                if col in df.columns:
                    df[col] = df[col].astype(float)
            
            df.set_index('timestamp', inplace=True)
            logger.info(f"✓ Successfully retrieved {len(df)} bars from database for '{symbol_to_use}'")
            return df
        except Exception as e:
            logger.error(f"Error retrieving data from database: {e}", exc_info=True)
            return None
        finally:
            self.db.pool.putconn(conn)

# Base Trading Bot Logic
class BaseCryptoTradingBot:
    def __init__(self, symbol='BTCUSD', max_daily_trades=3, quantity=0.001):
        self.symbol = symbol
        self.max_daily_trades = max_daily_trades
        self.daily_trades = 0
        self.last_trade_date = None
        self.atr_length = 14
        self.fvg_lookback = 3
        self.sweep_lookback = 3
        self.quantity = quantity
        self.stop_loss_pct = 0.02
        self.take_profit_pct = 0.04
        
    def reset_daily_counter(self):
        """Reset the daily trade counter if it's a new day"""
        current_date = datetime.now().date()
        if self.last_trade_date is None or current_date > self.last_trade_date:
            logger.info(f"New trading day: {current_date}. Resetting daily trade counter.")
            self.daily_trades = 0
            self.last_trade_date = current_date

    def calculate_atr(self, df: pd.DataFrame, length: int = 14) -> pd.Series:
        """Calculate Average True Range"""
        high = df['high']
        low = df['low']
        close = df['close'].shift(1)
        
        tr1 = high - low
        tr2 = abs(high - close)
        tr3 = abs(low - close)
        
        tr = pd.DataFrame({'tr1': tr1, 'tr2': tr2, 'tr3': tr3}).max(axis=1)
        atr = tr.rolling(window=length).mean()
        
        return atr

    def detect_sweep(self, df: pd.DataFrame):
        """Detect liquidity sweeps"""
        swing_low = df['low'].rolling(window=self.sweep_lookback).min().shift(2)
        swing_high = df['high'].rolling(window=self.sweep_lookback).max().shift(2)
        
        bullish_sweep = (df['low'].shift(2) == swing_low) & \
                         (df['low'].shift(1) < df['low'].shift(2)) & \
                         (df['close'] > df['high'].shift(2))
        
        bearish_sweep = (df['high'].shift(2) == swing_high) & \
                         (df['high'].shift(1) > df['high'].shift(2)) & \
                         (df['close'] < df['low'].shift(2))
        
        return bullish_sweep, bearish_sweep

    def detect_fvg(self, df: pd.DataFrame):
        """Detect Fair Value Gaps"""
        highest_high = df['high'].shift(1).rolling(window=self.fvg_lookback).max()
        lowest_low = df['low'].shift(1).rolling(window=self.fvg_lookback).min()
        
        bullish_fvg = df['low'] > highest_high
        bearish_fvg = df['high'] < lowest_low
        
        return bullish_fvg, bearish_fvg

    def check_for_signals(self, df: pd.DataFrame):
        """Check for trading signals in the data"""
        if df is None or len(df) == 0:
            logger.warning(f"Insufficient data for signal detection. DataFrame is None or empty")
            return None
        
        min_required = self.fvg_lookback + self.sweep_lookback + 5
        if len(df) < min_required:
            logger.warning(f"Insufficient data for signal detection. Have {len(df)} bars, need at least {min_required}")
            return None
        
        # Make a deep copy to avoid SettingWithCopyWarning when modifying
        df = df.copy(deep=True)
        
        # Calculate indicators - use .assign() to avoid SettingWithCopyWarning
        atr_series = self.calculate_atr(df, self.atr_length)
        df = df.assign(atr=atr_series)
        bullish_sweep, bearish_sweep = self.detect_sweep(df)
        bullish_fvg, bearish_fvg = self.detect_fvg(df)
        
        # Get latest signals
        latest = df.iloc[-1]
        
        # Convert price to float (handle Decimal types from database)
        try:
            price_value = float(latest['close'])
        except (TypeError, ValueError):
            price_value = 0.0
        
        # Handle NaN ATR - convert to float and replace with 0 if NaN
        try:
            atr_value = float(latest['atr'])
        except (TypeError, ValueError):
            atr_value = 0.0
        
        if pd.isna(atr_value) or atr_value is None:
            atr_value = 0.0
        
        signals = {
            'bullish_sweep': bullish_sweep.iloc[-1] if len(bullish_sweep) > 0 else False,
            'bearish_sweep': bearish_sweep.iloc[-1] if len(bearish_sweep) > 0 else False,
            'bullish_fvg': bullish_fvg.iloc[-1] if len(bullish_fvg) > 0 else False,
            'bearish_fvg': bearish_fvg.iloc[-1] if len(bearish_fvg) > 0 else False,
            'price': price_value,
            'atr': atr_value
        }
        
        # Only log if there's an actual signal to reduce verbosity
        if signals['bullish_sweep'] or signals['bearish_sweep'] or signals['bullish_fvg'] or signals['bearish_fvg']:
            logger.info(f"Signal detected: Price=${signals['price']:.2f}, "
                       f"BullishSweep={signals['bullish_sweep']}, BearishSweep={signals['bearish_sweep']}, "
                       f"BullishFVG={signals['bullish_fvg']}, BearishFVG={signals['bearish_fvg']}")
        
        return signals

# Backtest Bot using TimescaleDB
class TimescaleDBBacktestBot(BaseCryptoTradingBot):
    """Backtest bot that uses historical data from TimescaleDB"""
    
    def __init__(self, db: TimescaleDB, data_collector: HistoricalDataCollector, **kwargs):
        super().__init__(**kwargs)
        self.db = db
        self.data_collector = data_collector
        self.backtest_results = []
        self.current_mlflow_run = None
        self.positions = []  # Track open positions
        self.equity_curve = []  # Track equity over time
        self.initial_capital = 10000.0  # Starting capital
        self.current_capital = self.initial_capital
    
    def execute_trade(self, direction: str, price: float, atr_value: float, timestamp=None):
        """Simulate trade execution for backtesting"""
        if self.daily_trades >= self.max_daily_trades:
            logger.info(f"Maximum daily trades reached: {self.daily_trades}/{self.max_daily_trades}")
            return
        
        # Validate inputs - convert to float first to handle Decimal types
        try:
            price = float(price)
        except (TypeError, ValueError):
            logger.warning(f"Invalid price type: {type(price)}, value: {price}, skipping trade")
            return
        
        if price is None or np.isnan(price) or price <= 0:
            logger.warning(f"Invalid price: {price}, skipping trade")
            return
        
        # Handle NaN ATR - convert to float first
        try:
            atr_value = float(atr_value) if atr_value is not None else 0.0
        except (TypeError, ValueError):
            atr_value = 0.0
        
        atr_valid = not np.isnan(atr_value) and atr_value > 0
        
        # Calculate stop loss and take profit
        if direction == 'long':
            stop_price = price * (1 - self.stop_loss_pct)
            if atr_valid:
                take_profit = min(
                    price * (1 + self.take_profit_pct),
                    price + (2 * atr_value)
                )
            else:
                take_profit = price * (1 + self.take_profit_pct)
        else:  # short
            stop_price = price * (1 + self.stop_loss_pct)
            if atr_valid:
                take_profit = max(
                    price * (1 - self.take_profit_pct),
                    price - (2 * atr_value)
                )
            else:
                take_profit = price * (1 - self.take_profit_pct)
        
        logger.info(f"BACKTEST: Executed {direction.upper()} trade: {self.quantity} {self.symbol} at ${price:.2f}")
        logger.info(f"  Stop Loss: ${stop_price:.2f}, Take Profit: ${take_profit:.2f}")
        
        # Track position
        position = {
            'direction': direction,
            'entry_price': price,
            'stop_loss': stop_price,
            'take_profit': take_profit,
            'quantity': self.quantity,
            'entry_time': timestamp or datetime.now(),
            'entry_capital': self.current_capital
        }
        self.positions.append(position)
        
        # Save to database
        trade_id = None
        if self.db:
            # Ensure ATR is a valid float (handle NaN)
            atr_for_db = float(atr_value) if (atr_value is not None and not np.isnan(atr_value)) else 0.0
            
            trade_id = self.db.insert_trade({
                'symbol': self.symbol,
                'direction': direction,
                'quantity': float(self.quantity),
                'entry_price': float(price),
                'stop_loss': float(stop_price),
                'take_profit': float(take_profit),
                'atr_value': atr_for_db,
                'daily_trade_number': self.daily_trades + 1,
                'mlflow_run_id': self.current_mlflow_run.info.run_id if self.current_mlflow_run else None
            })
        
        self.daily_trades += 1
        self.backtest_results.append({
            'direction': direction,
            'entry_price': price,
            'stop_loss': stop_price,
            'take_profit': take_profit,
            'trade_id': trade_id,
            'entry_time': timestamp or datetime.now()
        })
    
    def calculate_metrics(self, df: pd.DataFrame):
        """Calculate performance metrics including Sharpe ratio"""
        if len(self.backtest_results) == 0:
            return {}
        
        # Calculate returns for each trade
        returns = []
        closed_trades = []
        
        for i, trade in enumerate(self.backtest_results):
            entry_price = trade['entry_price']
            entry_time = trade['entry_time']
            
            # Find closest index (handle timestamp matching)
            try:
                if entry_time in df.index:
                    entry_idx = df.index.get_loc(entry_time)
                else:
                    # Find closest timestamp
                    entry_idx = df.index.searchsorted(entry_time)
                    if entry_idx >= len(df):
                        entry_idx = len(df) - 1
            except Exception:
                continue
            
            # Find exit (stop loss or take profit hit)
            direction = trade['direction']
            stop_loss = trade['stop_loss']
            take_profit = trade['take_profit']
            
            exit_price = None
            exit_reason = None
            
            # Check subsequent bars for exit
            for j in range(entry_idx + 1, min(entry_idx + 100, len(df))):
                bar = df.iloc[j]
                
                if direction == 'long':
                    # Check stop loss
                    if bar['low'] <= stop_loss:
                        exit_price = stop_loss
                        exit_reason = 'stop_loss'
                        break
                    # Check take profit
                    elif bar['high'] >= take_profit:
                        exit_price = take_profit
                        exit_reason = 'take_profit'
                        break
                else:  # short
                    # Check stop loss
                    if bar['high'] >= stop_loss:
                        exit_price = stop_loss
                        exit_reason = 'stop_loss'
                        break
                    # Check take profit
                    elif bar['low'] <= take_profit:
                        exit_price = take_profit
                        exit_reason = 'take_profit'
                        break
            
            # If no exit found, use last bar price
            if exit_price is None:
                exit_price = df.iloc[-1]['close']
                exit_reason = 'end_of_data'
            
            # Calculate return
            if direction == 'long':
                trade_return = (exit_price - entry_price) / entry_price
            else:  # short
                trade_return = (entry_price - exit_price) / entry_price
            
            returns.append(trade_return)
            closed_trades.append({
                'entry_price': entry_price,
                'exit_price': exit_price,
                'direction': direction,
                'return': trade_return,
                'exit_reason': exit_reason
            })
        
        if len(returns) == 0:
            return {}
        
        returns_array = np.array(returns)
        
        # Calculate metrics
        total_return = np.sum(returns_array)
        total_trades = len(returns)
        winning_trades = len([r for r in returns if r > 0])
        losing_trades = len([r for r in returns if r < 0])
        win_rate = winning_trades / total_trades if total_trades > 0 else 0
        
        avg_return = np.mean(returns_array)
        std_return = np.std(returns_array)
        
        # Sharpe ratio (annualized, assuming 252 trading days)
        # For 5-min bars: 288 bars per day, so annualization factor
        bars_per_day = 288  # 5-min bars in a day
        trading_days = len(df) / bars_per_day
        sharpe_ratio = (avg_return / std_return * np.sqrt(bars_per_day)) if std_return > 0 else 0
        
        # Maximum drawdown
        cumulative_returns = np.cumsum(returns_array)
        running_max = np.maximum.accumulate(cumulative_returns)
        drawdown = cumulative_returns - running_max
        max_drawdown = np.min(drawdown) if len(drawdown) > 0 else 0
        
        # Profit factor
        gross_profit = sum([r for r in returns if r > 0])
        gross_loss = abs(sum([r for r in returns if r < 0]))
        profit_factor = gross_profit / gross_loss if gross_loss > 0 else float('inf')
        
        # Average win/loss
        avg_win = np.mean([r for r in returns if r > 0]) if winning_trades > 0 else 0
        avg_loss = np.mean([r for r in returns if r < 0]) if losing_trades > 0 else 0
        
        # Final equity
        final_equity = self.initial_capital * (1 + total_return)
        
        metrics = {
            'total_trades': total_trades,
            'winning_trades': winning_trades,
            'losing_trades': losing_trades,
            'win_rate': win_rate,
            'total_return': total_return,
            'total_return_pct': total_return * 100,
            'avg_return': avg_return,
            'avg_return_pct': avg_return * 100,
            'sharpe_ratio': sharpe_ratio,
            'max_drawdown': max_drawdown,
            'max_drawdown_pct': max_drawdown * 100,
            'profit_factor': profit_factor,
            'avg_win': avg_win,
            'avg_win_pct': avg_win * 100,
            'avg_loss': avg_loss,
            'avg_loss_pct': avg_loss * 100,
            'initial_capital': self.initial_capital,
            'final_equity': final_equity,
            'net_profit': final_equity - self.initial_capital,
            'roi': (final_equity - self.initial_capital) / self.initial_capital * 100
        }
        
        return metrics
    
    def run_backtest_from_db(self, start_date: str, end_date: str, timeframe: str = '5Min'):
        """Run backtest using data from TimescaleDB"""
        logger.info(f"Starting backtest from {start_date} to {end_date}")
        logger.info(f"Requested symbol: {self.symbol}")
        
        # Try to get data - the function will automatically find the correct symbol format
        # The get_historical_data_from_db method handles symbol matching internally
        df = self.data_collector.get_historical_data_from_db(
            self.symbol, start_date, end_date, timeframe
        )
        
        # If not found, try with alternative symbol formats as fallback
        if df is None or len(df) == 0:
            logger.warning(f"Initial query with '{self.symbol}' returned no data. Trying alternative formats...")
            # Try alternative symbol formats
            alt_symbols = ['BTC/USD', 'BTCUSD', 'BTC-USD']
            for alt_symbol in alt_symbols:
                if alt_symbol != self.symbol:
                    logger.info(f"Trying alternative symbol format: {alt_symbol}")
                    df = self.data_collector.get_historical_data_from_db(
                        alt_symbol, start_date, end_date, timeframe
                    )
                    if df is not None and len(df) > 0:
                        logger.info(f"✓ Found data with symbol format: {alt_symbol}")
                        # Update self.symbol to match what was found
                        self.symbol = alt_symbol
                        break
        
        if df is None or len(df) == 0:
            logger.error("No data found in database. Run data collection first!")
            logger.error(f"Tried symbol: {self.symbol} and alternatives: BTC/USD, BTCUSD, BTC-USD")
            return None
        
        logger.info(f"Backtesting on {len(df)} bars from database")
        
        # Validate DataFrame has required columns
        required_cols = ['open', 'high', 'low', 'close', 'volume']
        missing_cols = [col for col in required_cols if col not in df.columns]
        if missing_cols:
            logger.error(f"DataFrame missing required columns: {missing_cols}")
            return None
        
        # Ensure DataFrame is properly formatted (iloc works with any index type)
        # Just verify the DataFrame is not empty and has valid data
        if df.empty:
            logger.error("DataFrame is empty after retrieval")
            return None
        
        # MLflow experiment
        mlflow.set_experiment("btc_backtest_db")
        self.current_mlflow_run = mlflow.start_run()
        
        try:
            mlflow.log_param("symbol", self.symbol)
            mlflow.log_param("start_date", start_date)
            mlflow.log_param("end_date", end_date)
            mlflow.log_param("timeframe", timeframe)
            mlflow.log_param("max_daily_trades", self.max_daily_trades)
            mlflow.log_param("stop_loss_pct", self.stop_loss_pct)
            mlflow.log_param("take_profit_pct", self.take_profit_pct)
            mlflow.log_param("initial_capital", self.initial_capital)
            
            # Walk-forward backtest
            # Start from index that ensures we have enough lookback data
            min_lookback = max(50, self.fvg_lookback + self.sweep_lookback + 5)
            start_idx = min_lookback
            
            # Validate that we have enough data
            if len(df) < min_lookback + 1:
                logger.error(f"Insufficient data for backtest. Need at least {min_lookback + 1} bars, but have {len(df)}")
                return None
            
            logger.info(f"Starting backtest loop from index {start_idx} to {len(df)-1} (total bars: {len(df)})")
            
            for i in range(start_idx, len(df)):
                # Ensure we always have at least 50 bars, starting from 0 if needed
                lookback_start = max(0, i - 50)
                
                # Validate indices before slicing
                if lookback_start >= len(df) or i+1 > len(df):
                    logger.warning(f"Invalid indices at i={i}: lookback_start={lookback_start}, i+1={i+1}, df_len={len(df)}")
                    continue
                
                # Use iloc to slice, then explicitly copy to avoid any view issues
                try:
                    lookback_data = df.iloc[lookback_start:i+1].copy(deep=True)  # +1 to include current bar
                except Exception as e:
                    logger.warning(f"Error slicing DataFrame at index {i}: {e}")
                    continue
                
                # Validate the slice has data
                if len(lookback_data) == 0:
                    logger.warning(f"Empty DataFrame slice at index {i} (lookback_start={lookback_start}, i+1={i+1}, df_len={len(df)})")
                    continue
                
                # Validate required columns exist in slice
                if not all(col in lookback_data.columns for col in required_cols):
                    logger.warning(f"Missing required columns in slice at index {i}")
                    continue
                
                signals = self.check_for_signals(lookback_data)
                
                if signals:
                    current_timestamp = df.index[i]
                    if signals['bullish_sweep'] and signals['bullish_fvg']:
                        self.execute_trade('long', signals['price'], signals['atr'], current_timestamp)
                    elif signals['bearish_sweep'] and signals['bearish_fvg']:
                        self.execute_trade('short', signals['price'], signals['atr'], current_timestamp)
                
                # Progress logging
                if i % 100 == 0:
                    logger.info(f"Backtest progress: {i}/{len(df)} bars ({i/len(df)*100:.1f}%)")
            
            # Calculate metrics
            metrics = self.calculate_metrics(df)
            
            logger.info(f"\n{'='*60}")
            logger.info("BACKTEST RESULTS")
            logger.info(f"{'='*60}")
            logger.info(f"Total Trades: {metrics.get('total_trades', 0)}")
            logger.info(f"Winning Trades: {metrics.get('winning_trades', 0)}")
            logger.info(f"Losing Trades: {metrics.get('losing_trades', 0)}")
            logger.info(f"Win Rate: {metrics.get('win_rate', 0)*100:.2f}%")
            logger.info(f"\nPerformance Metrics:")
            logger.info(f"Total Return: {metrics.get('total_return_pct', 0):.2f}%")
            logger.info(f"ROI: {metrics.get('roi', 0):.2f}%")
            logger.info(f"Initial Capital: ${metrics.get('initial_capital', 0):,.2f}")
            logger.info(f"Final Equity: ${metrics.get('final_equity', 0):,.2f}")
            logger.info(f"Net Profit: ${metrics.get('net_profit', 0):,.2f}")
            logger.info(f"\nRisk Metrics:")
            logger.info(f"Sharpe Ratio: {metrics.get('sharpe_ratio', 0):.4f}")
            logger.info(f"Max Drawdown: {metrics.get('max_drawdown_pct', 0):.2f}%")
            logger.info(f"Profit Factor: {metrics.get('profit_factor', 0):.4f}")
            logger.info(f"Average Win: {metrics.get('avg_win_pct', 0):.2f}%")
            logger.info(f"Average Loss: {metrics.get('avg_loss_pct', 0):.2f}%")
            logger.info(f"{'='*60}\n")
            
            # Log to MLflow
            mlflow.log_metric("total_trades", metrics.get('total_trades', 0))
            mlflow.log_metric("winning_trades", metrics.get('winning_trades', 0))
            mlflow.log_metric("losing_trades", metrics.get('losing_trades', 0))
            mlflow.log_metric("win_rate", metrics.get('win_rate', 0))
            mlflow.log_metric("total_return_pct", metrics.get('total_return_pct', 0))
            mlflow.log_metric("roi", metrics.get('roi', 0))
            mlflow.log_metric("final_equity", metrics.get('final_equity', 0))
            mlflow.log_metric("net_profit", metrics.get('net_profit', 0))
            mlflow.log_metric("sharpe_ratio", metrics.get('sharpe_ratio', 0))
            mlflow.log_metric("max_drawdown_pct", metrics.get('max_drawdown_pct', 0))
            mlflow.log_metric("profit_factor", metrics.get('profit_factor', 0))
            mlflow.log_metric("avg_win_pct", metrics.get('avg_win_pct', 0))
            mlflow.log_metric("avg_loss_pct", metrics.get('avg_loss_pct', 0))
            
            # Store metrics in TimescaleDB for Grafana visualization
            if self.db:
                metrics_for_db = metrics.copy()
                metrics_for_db.update({
                    'start_date': start_date,
                    'end_date': end_date,
                    'symbol': self.symbol,
                    'timeframe': timeframe,
                    'mlflow_run_id': self.current_mlflow_run.info.run_id if self.current_mlflow_run else None
                })
                result_id = self.db.insert_backtest_results(metrics_for_db)
                if result_id:
                    logger.info(f"Backtest metrics saved to TimescaleDB with ID: {result_id}")
            
            return metrics
            
        finally:
            mlflow.end_run()

# Configuration
class BacktestConfig:
    def __init__(self):
        # Alpaca credentials
        self.ALPACA_API_KEY = os.getenv('ALPACA_API_KEY', 'PKSWFXHIT7WAESKFYXTTJ6DKUE')
        self.ALPACA_API_SECRET = os.getenv('ALPACA_API_SECRET', 'A4nDUtAxdWijWjmg4zPVXcPeciaKhfkzwJ2wVF4gS5sg')
        
        # TimescaleDB configuration
        self.TIMESCALEDB_URL = os.getenv(
            'TIMESCALEDB_URL', 
            'postgresql://rayhan:12102801Rr@timescaledb:5432/arafatdb'
        )
        
        # MLflow configuration
        self.MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI', 'http://mlflow:5000')
        
        # Loki configuration
        self.LOKI_URL = os.getenv('LOKI_URL', 'http://loki:3100/loki/api/v1/push')
        
        # Initialize connections
        self.db = TimescaleDB(self.TIMESCALEDB_URL)
        mlflow.set_tracking_uri(self.MLFLOW_TRACKING_URI)
        
        # Setup logging with Loki
        global logger
        logger = setup_logging(
            level=logging.INFO,
            loki_url=self.LOKI_URL,
            loki_labels={'service': 'btc_backtest'}
        )

# Main execution
if __name__ == "__main__":
    config = BacktestConfig()
    
    # Create data collector
    collector = HistoricalDataCollector(
        db=config.db,
        api_key=config.ALPACA_API_KEY,
        api_secret=config.ALPACA_API_SECRET
    )
    
    # STEP 1: Collect historical data (UNCOMMENT AND RUN THIS FIRST!)
    print("="*60)
    print("STEP 1: BTC Historical Data Collection")
    print("="*60)
    print("\n⚠️  IMPORTANT: Uncomment the lines below to collect historical data FIRST!")
    print("This will take 30-60 minutes depending on date range.\n")
    
    # ⬇️ UNCOMMENT THE LINES BELOW TO COLLECT DATA ⬇️
    # collector.collect_historical_data(
    #     symbol='BTCUSD',
    #     start_date='2020-01-01',  # Start date
    #     end_date='2024-12-31',     # End date
    #     timeframe='5Min'           # 5-minute bars
    # )
    # ⬆️ UNCOMMENT THE LINES ABOVE TO COLLECT DATA ⬆️
    
    # STEP 2: Run backtest using collected data
    print("\n" + "="*60)
    print("STEP 2: BTC Backtest")
    print("="*60)
    print("\n⚠️  Make sure you've collected data first (Step 1)!\n")
    
    # Check if data exists before running backtest
    # Try both symbol formats (BTCUSD and BTC/USD)
    test_df = collector.get_historical_data_from_db(
        'BTCUSD', '2021-01-01', '2022-12-31', '5Min'
    )
    
    # If not found, try with slash format
    if test_df is None or len(test_df) == 0:
        logger.info("Trying with BTC/USD format...")
        test_df = collector.get_historical_data_from_db(
            'BTC/USD', '2021-01-01', '2022-12-31', '5Min'
        )
    
    if test_df is None or len(test_df) == 0:
        print("❌ ERROR: No data found in database!")
        print("\nPlease run data collection first:")
        print("1. Uncomment the collector.collect_historical_data() lines above")
        print("2. Run this cell again")
        print("3. Wait for data collection to complete (30-60 minutes)")
        print("4. Then run the backtest section below")
    else:
        print(f"✅ Found {len(test_df)} bars in database. Running backtest...\n")
        
        backtest_bot = TimescaleDBBacktestBot(
            db=config.db,
            data_collector=collector,
            symbol='BTCUSD',
            max_daily_trades=3,
            quantity=0.001
        )
        
        # Run backtest (use same dates as data collection)
        metrics = backtest_bot.run_backtest_from_db(
            start_date='2021-01-01',
            end_date='2022-12-31',
            timeframe='5Min'
        )
        
        if metrics:
            print(f"\n{'='*60}")
            print("BACKTEST SUMMARY")
            print(f"{'='*60}")
            print(f"Total Trades: {metrics.get('total_trades', 0)}")
            print(f"Long Trades: {len([t for t in backtest_bot.backtest_results if t['direction'] == 'long'])}")
            print(f"Short Trades: {len([t for t in backtest_bot.backtest_results if t['direction'] == 'short'])}")
            print(f"\nSharpe Ratio: {metrics.get('sharpe_ratio', 0):.4f}")
            print(f"Total Return: {metrics.get('total_return_pct', 0):.2f}%")
            print(f"ROI: {metrics.get('roi', 0):.2f}%")
            print(f"Max Drawdown: {metrics.get('max_drawdown_pct', 0):.2f}%")
            print(f"Profit Factor: {metrics.get('profit_factor', 0):.4f}")
            print(f"Win Rate: {metrics.get('win_rate', 0)*100:.2f}%")
            print(f"{'='*60}")
# Out:
# 2025-11-14 18:37:26,095 - WARNING - Could not create hypertable (may be regular PostgreSQL)
# 2025-11-14 18:37:26,096 - ERROR - ❌ Schema initialization error: current transaction is aborted, commands ignored until end of transaction block
# Traceback (most recent call last):
#   File "/tmp/ipykernel_15775/813405135.py", line 174, in _init_schema
#     cur.execute("""
# psycopg2.errors.InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block
#
# 2025-11-14 18:37:26,097 - INFO - ✓ Trades table created successfully (fallback)
# 2025-11-14 18:37:26,097 - INFO - TimescaleDB connection pool created
# 2025-11-14 18:37:26,099 - INFO - OHLCV table created/verified
# ============================================================
# STEP 1: BTC Historical Data Collection
# ============================================================
#
# ⚠️  IMPORTANT: Uncomment the lines below to collect historical data FIRST!
# This will take 30-60 minutes depending on date range.
#
#
# ============================================================
# STEP 2: BTC Backtest
# ============================================================
#
# ⚠️  Make sure you've collected data first (Step 1)!
#
# 2025-11-14 18:37:26,177 - INFO - Symbols found in database: ['BTC/USD']
# 2025-11-14 18:37:26,179 - INFO - Looking for symbol: BTCUSD (normalized: BTCUSD)
# 2025-11-14 18:37:26,191 - INFO - Timeframes found in database: ['5Min']
# 2025-11-14 18:37:26,193 - INFO - ✓ Found normalized match: 'BTCUSD' -> 'BTC/USD' (DB has 'BTC/USD', normalized to 'BTCUSD')
# 2025-11-14 18:37:26,195 - INFO - Executing query: symbol='BTC/USD', timeframe='5Min', start=2021-01-01 00:00:00+00:00, end=2023-01-01 00:00:00+00:00
# 2025-11-14 18:37:26,376 - INFO - ✓ Successfully retrieved 49000 bars from database for 'BTC/USD'
# ✅ Found 49000 bars in database. Running backtest...
#
# 2025-11-14 18:37:26,381 - INFO - Starting backtest from 2021-01-01 to 2022-12-31
# 2025-11-14 18:37:26,383 - INFO - Requested symbol: BTCUSD
# 2025-11-14 18:37:26,393 - INFO - Symbols found in database: ['BTC/USD']
# 2025-11-14 18:37:26,394 - INFO - Looking for symbol: BTCUSD (normalized: BTCUSD)
# 2025-11-14 18:37:26,404 - INFO - Timeframes found in database: ['5Min']
# 2025-11-14 18:37:26,405 - INFO - ✓ Found normalized match: 'BTCUSD' -> 'BTC/USD' (DB has 'BTC/USD', normalized to 'BTCUSD')
# 2025-11-14 18:37:26,407 - INFO - Executing query: symbol='BTC/USD', timeframe='5Min', start=2021-01-01 00:00:00+00:00, end=2023-01-01 00:00:00+00:00
# 2025-11-14 18:37:26,578 - INFO - ✓ Successfully retrieved 49000 bars from database for 'BTC/USD'
# 2025-11-14 18:37:26,583 - INFO - Backtesting on 49000 bars from database
# 2025-11-14 18:37:26,709 - INFO - Starting backtest loop from index 50 to 48999 (total bars: 49000)
# 2025-11-14 18:37:26,714 - INFO - Signal detected: Price=$29353.06, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:26,718 - INFO - Signal detected: Price=$29309.26, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:26,743 - INFO - Signal detected: Price=$29372.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:26,746 - INFO - Signal detected: Price=$29378.85, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:26,826 - INFO - Backtest progress: 100/49000 bars (0.2%)
# 2025-11-14 18:37:26,953 - INFO - Signal detected: Price=$29335.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:26,986 - INFO - Signal detected: Price=$29078.07, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,017 - INFO - Signal detected: Price=$29148.79, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,026 - INFO - Signal detected: Price=$29186.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,029 - INFO - Signal detected: Price=$29189.96, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,060 - INFO - Signal detected: Price=$29319.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,089 - INFO - Backtest progress: 200/49000 bars (0.4%)
# 2025-11-14 18:37:27,138 - INFO - Signal detected: Price=$29205.18, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,202 - INFO - Signal detected: Price=$29392.61, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,272 - INFO - Backtest progress: 300/49000 bars (0.6%)
# 2025-11-14 18:37:27,295 - INFO - Signal detected: Price=$29829.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,351 - INFO - Signal detected: Price=$29833.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,357 - INFO - Signal detected: Price=$29696.32, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,373 - INFO - Signal detected: Price=$29826.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,377 - INFO - Signal detected: Price=$29745.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,460 - INFO - Backtest progress: 400/49000 bars (0.8%)
# 2025-11-14 18:37:27,491 - INFO - Signal detected: Price=$32334.97, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,523 - INFO - Signal detected: Price=$32638.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,602 - INFO - Signal detected: Price=$31452.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,631 - INFO - Backtest progress: 500/49000 bars (1.0%)
# 2025-11-14 18:37:27,633 - INFO - Signal detected: Price=$32055.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,648 - INFO - Signal detected: Price=$32442.10, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:27,693 - INFO - Signal detected: Price=$32812.99, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,723 - INFO - Signal detected: Price=$32648.58, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,765 - INFO - Signal detected: Price=$33900.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,785 - INFO - Backtest progress: 600/49000 bars (1.2%)
# 2025-11-14 18:37:27,849 - INFO - Signal detected: Price=$34117.04, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,906 - INFO - Signal detected: Price=$33989.72, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,934 - INFO - Signal detected: Price=$33419.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,950 - INFO - Backtest progress: 700/49000 bars (1.4%)
# 2025-11-14 18:37:27,972 - INFO - Signal detected: Price=$33125.54, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:27,987 - INFO - Signal detected: Price=$32902.01, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,013 - INFO - Signal detected: Price=$32723.57, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,030 - INFO - Signal detected: Price=$32681.97, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,033 - INFO - Signal detected: Price=$32679.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,039 - INFO - Signal detected: Price=$33159.74, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,051 - INFO - Signal detected: Price=$33617.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,080 - INFO - Signal detected: Price=$33590.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,097 - INFO - Signal detected: Price=$33439.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,121 - INFO - Signal detected: Price=$32817.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,126 - INFO - Backtest progress: 800/49000 bars (1.6%)
# 2025-11-14 18:37:28,141 - INFO - Signal detected: Price=$32880.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,143 - INFO - Signal detected: Price=$33090.39, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,167 - INFO - Signal detected: Price=$33347.42, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,195 - INFO - Signal detected: Price=$33519.76, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,210 - INFO - Signal detected: Price=$33212.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,215 - INFO - Signal detected: Price=$33305.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,221 - INFO - Signal detected: Price=$33149.42, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,223 - INFO - Signal detected: Price=$33105.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,251 - INFO - Signal detected: Price=$33260.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,283 - INFO - Signal detected: Price=$32015.18, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,287 - INFO - Backtest progress: 900/49000 bars (1.8%)
# 2025-11-14 18:37:28,291 - INFO - Signal detected: Price=$31735.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,331 - INFO - Signal detected: Price=$30071.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,400 - INFO - Signal detected: Price=$31054.36, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,411 - INFO - Signal detected: Price=$31020.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,460 - INFO - Signal detected: Price=$32054.59, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,499 - INFO - Signal detected: Price=$32232.63, BullishSweep=True, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,500 - INFO - BACKTEST: Executed LONG trade: 0.001 BTCUSD at $32232.63
# 2025-11-14 18:37:28,501 - INFO -   Stop Loss: $31587.98, Take Profit: $32886.16
# 2025-11-14 18:37:28,510 - INFO - Backtest progress: 1000/49000 bars (2.0%)
# 2025-11-14 18:37:28,527 - INFO - Signal detected: Price=$32609.74, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,540 - INFO - Signal detected: Price=$32548.27, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,570 - INFO - Signal detected: Price=$32679.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,593 - INFO - Signal detected: Price=$33472.23, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:28,605 - INFO - Signal detected: Price=$33496.31, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,630 - INFO - Signal detected: Price=$33387.10, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,675 - INFO - Backtest progress: 1100/49000 bars (2.2%)
# 2025-11-14 18:37:28,740 - INFO - Signal detected: Price=$33274.48, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,756 - INFO - Signal detected: Price=$33537.59, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,777 - INFO - Signal detected: Price=$34645.81, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:28,781 - INFO - Signal detected: Price=$34443.55, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,802 - INFO - Signal detected: Price=$34582.93, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,814 - INFO - Signal detected: Price=$34395.95, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,826 - INFO - Signal detected: Price=$34445.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,833 - INFO - Signal detected: Price=$34165.33, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,847 - INFO - Backtest progress: 1200/49000 bars (2.4%)
# 2025-11-14 18:37:28,873 - INFO - Signal detected: Price=$33921.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,876 - INFO - Signal detected: Price=$33910.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,935 - INFO - Signal detected: Price=$33441.49, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,940 - INFO - Signal detected: Price=$32840.46, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,968 - INFO - Signal detected: Price=$32385.43, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:28,997 - INFO - Signal detected: Price=$32435.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,017 - INFO - Backtest progress: 1300/49000 bars (2.7%)
# 2025-11-14 18:37:29,173 - INFO - Signal detected: Price=$31986.25, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:29,176 - INFO - Signal detected: Price=$31919.12, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:29,190 - INFO - Signal detected: Price=$31709.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,245 - INFO - Backtest progress: 1400/49000 bars (2.9%)
# 2025-11-14 18:37:29,255 - INFO - Signal detected: Price=$31429.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,259 - INFO - Signal detected: Price=$31803.32, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,302 - INFO - Signal detected: Price=$31741.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,316 - INFO - Signal detected: Price=$31419.29, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,323 - INFO - Signal detected: Price=$31465.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,351 - INFO - Signal detected: Price=$31344.94, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,377 - INFO - Signal detected: Price=$31521.05, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,406 - INFO - Backtest progress: 1500/49000 bars (3.1%)
# 2025-11-14 18:37:29,413 - INFO - Signal detected: Price=$32057.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,415 - INFO - Signal detected: Price=$31951.38, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,437 - INFO - Signal detected: Price=$32176.87, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,456 - INFO - Signal detected: Price=$32275.81, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,478 - INFO - Signal detected: Price=$31999.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,484 - INFO - Signal detected: Price=$32128.17, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,495 - INFO - Signal detected: Price=$32100.22, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,540 - INFO - Signal detected: Price=$32002.30, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,559 - INFO - Signal detected: Price=$32148.14, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,566 - INFO - Backtest progress: 1600/49000 bars (3.3%)
# 2025-11-14 18:37:29,575 - INFO - Signal detected: Price=$32133.18, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,601 - INFO - Signal detected: Price=$31649.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,618 - INFO - Signal detected: Price=$31804.31, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,676 - INFO - Signal detected: Price=$31822.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,687 - INFO - Signal detected: Price=$31554.41, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,720 - INFO - Backtest progress: 1700/49000 bars (3.5%)
# 2025-11-14 18:37:29,742 - INFO - Signal detected: Price=$31567.89, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,754 - INFO - Signal detected: Price=$30498.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,758 - INFO - Signal detected: Price=$30647.50, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,859 - INFO - Signal detected: Price=$30597.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,879 - INFO - Signal detected: Price=$30083.53, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,883 - INFO - Backtest progress: 1800/49000 bars (3.7%)
# 2025-11-14 18:37:29,927 - INFO - Signal detected: Price=$31411.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,970 - INFO - Signal detected: Price=$30499.08, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,980 - INFO - Signal detected: Price=$30137.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,988 - INFO - Signal detected: Price=$30302.30, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:29,995 - INFO - Signal detected: Price=$30260.74, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,021 - INFO - Signal detected: Price=$30920.00, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:30,039 - INFO - Backtest progress: 1900/49000 bars (3.9%)
# 2025-11-14 18:37:30,059 - INFO - Signal detected: Price=$31400.24, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,070 - INFO - Signal detected: Price=$31290.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,085 - INFO - Signal detected: Price=$31313.41, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,158 - INFO - Signal detected: Price=$31196.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,178 - INFO - Signal detected: Price=$31239.22, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,192 - INFO - Signal detected: Price=$34309.75, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:30,193 - INFO - Backtest progress: 2000/49000 bars (4.1%)
# 2025-11-14 18:37:30,229 - INFO - Signal detected: Price=$33997.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,233 - INFO - Signal detected: Price=$34234.09, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,274 - INFO - Signal detected: Price=$34062.57, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,276 - INFO - Signal detected: Price=$34053.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,361 - INFO - Backtest progress: 2100/49000 bars (4.3%)
# 2025-11-14 18:37:30,374 - INFO - Signal detected: Price=$33748.27, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:30,395 - INFO - Signal detected: Price=$33486.11, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,421 - INFO - Signal detected: Price=$33551.80, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:30,429 - INFO - Signal detected: Price=$33452.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,436 - INFO - Signal detected: Price=$33579.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,476 - INFO - Signal detected: Price=$33452.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,508 - INFO - Backtest progress: 2200/49000 bars (4.5%)
# 2025-11-14 18:37:30,524 - INFO - Signal detected: Price=$32811.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,629 - INFO - Signal detected: Price=$33158.84, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,650 - INFO - Signal detected: Price=$32873.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,668 - INFO - Backtest progress: 2300/49000 bars (4.7%)
# 2025-11-14 18:37:30,709 - INFO - Signal detected: Price=$33580.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,737 - INFO - Signal detected: Price=$33621.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,777 - INFO - Signal detected: Price=$33474.82, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,791 - INFO - Signal detected: Price=$33765.55, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,809 - INFO - Signal detected: Price=$33800.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,823 - INFO - Backtest progress: 2400/49000 bars (4.9%)
# 2025-11-14 18:37:30,854 - INFO - Signal detected: Price=$34139.13, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,905 - INFO - Signal detected: Price=$33722.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,908 - INFO - Signal detected: Price=$33770.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,959 - INFO - Signal detected: Price=$33483.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:30,977 - INFO - Backtest progress: 2500/49000 bars (5.1%)
# 2025-11-14 18:37:31,023 - INFO - Signal detected: Price=$33940.49, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,061 - INFO - Signal detected: Price=$33685.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,063 - INFO - Signal detected: Price=$33702.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,083 - INFO - Signal detected: Price=$33525.90, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:31,128 - INFO - Backtest progress: 2600/49000 bars (5.3%)
# 2025-11-14 18:37:31,225 - INFO - Signal detected: Price=$34237.66, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,244 - INFO - Signal detected: Price=$34350.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,279 - INFO - Backtest progress: 2700/49000 bars (5.5%)
# 2025-11-14 18:37:31,299 - INFO - Signal detected: Price=$35151.32, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,332 - INFO - Signal detected: Price=$35220.18, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:31,349 - INFO - Signal detected: Price=$34709.50, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,363 - INFO - Signal detected: Price=$34737.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,367 - INFO - Signal detected: Price=$34865.38, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,372 - INFO - Signal detected: Price=$34759.93, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,426 - INFO - Backtest progress: 2800/49000 bars (5.7%)
# 2025-11-14 18:37:31,454 - INFO - Signal detected: Price=$35677.21, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,482 - INFO - Signal detected: Price=$35793.74, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,578 - INFO - Backtest progress: 2900/49000 bars (5.9%)
# 2025-11-14 18:37:31,711 - INFO - Signal detected: Price=$35899.97, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,737 - INFO - Signal detected: Price=$48661.18, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:31,738 - INFO - Backtest progress: 3000/49000 bars (6.1%)
# 2025-11-14 18:37:31,743 - INFO - Signal detected: Price=$47781.78, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:31,814 - INFO - Signal detected: Price=$51005.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,817 - INFO - Signal detected: Price=$51005.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,841 - INFO - Signal detected: Price=$50258.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,846 - INFO - Signal detected: Price=$50497.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,848 - INFO - Signal detected: Price=$50502.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,851 - INFO - Signal detected: Price=$49773.22, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,871 - INFO - Signal detected: Price=$49927.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,888 - INFO - Backtest progress: 3100/49000 bars (6.3%)
# 2025-11-14 18:37:31,904 - INFO - Signal detected: Price=$50918.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,971 - INFO - Signal detected: Price=$50927.20, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:31,997 - INFO - Signal detected: Price=$49405.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,018 - INFO - Signal detected: Price=$49180.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,041 - INFO - Backtest progress: 3200/49000 bars (6.5%)
# 2025-11-14 18:37:32,136 - INFO - Signal detected: Price=$48790.70, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,177 - INFO - Signal detected: Price=$50151.40, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,189 - INFO - Backtest progress: 3300/49000 bars (6.7%)
# 2025-11-14 18:37:32,207 - INFO - Signal detected: Price=$50774.51, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,215 - INFO - Signal detected: Price=$50610.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,285 - INFO - Signal detected: Price=$50440.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,307 - INFO - Signal detected: Price=$50508.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,343 - INFO - Backtest progress: 3400/49000 bars (6.9%)
# 2025-11-14 18:37:32,378 - INFO - Signal detected: Price=$49643.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,410 - INFO - Signal detected: Price=$51483.83, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,427 - INFO - Signal detected: Price=$51408.98, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,450 - INFO - Signal detected: Price=$50940.72, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,487 - INFO - Backtest progress: 3500/49000 bars (7.1%)
# 2025-11-14 18:37:32,535 - INFO - Signal detected: Price=$48733.94, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,566 - INFO - Signal detected: Price=$48039.27, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,635 - INFO - Backtest progress: 3600/49000 bars (7.3%)
# 2025-11-14 18:37:32,637 - INFO - Signal detected: Price=$46605.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,735 - INFO - Signal detected: Price=$45283.50, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:32,775 - INFO - Backtest progress: 3700/49000 bars (7.6%)
# 2025-11-14 18:37:32,785 - INFO - Signal detected: Price=$46696.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,790 - INFO - Signal detected: Price=$46406.15, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,802 - INFO - Signal detected: Price=$46343.40, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,837 - INFO - Signal detected: Price=$45918.69, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,866 - INFO - Signal detected: Price=$47478.02, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,918 - INFO - Backtest progress: 3800/49000 bars (7.8%)
# 2025-11-14 18:37:32,937 - INFO - Signal detected: Price=$47028.98, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,957 - INFO - Signal detected: Price=$46288.05, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,981 - INFO - Signal detected: Price=$45706.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,983 - INFO - Signal detected: Price=$45718.18, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:32,998 - INFO - Signal detected: Price=$46065.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,070 - INFO - Signal detected: Price=$47920.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,080 - INFO - Backtest progress: 3900/49000 bars (8.0%)
# 2025-11-14 18:37:33,098 - INFO - Signal detected: Price=$47418.60, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,101 - INFO - Signal detected: Price=$47650.90, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,142 - INFO - Signal detected: Price=$47711.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,160 - INFO - Signal detected: Price=$48297.47, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:33,175 - INFO - Signal detected: Price=$47121.25, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,190 - INFO - Signal detected: Price=$47030.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,193 - INFO - Signal detected: Price=$46721.24, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:33,211 - INFO - Signal detected: Price=$46736.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,246 - INFO - Signal detected: Price=$46798.86, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,252 - INFO - Signal detected: Price=$47083.25, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,255 - INFO - Signal detected: Price=$49830.75, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:33,256 - INFO - Backtest progress: 4000/49000 bars (8.2%)
# 2025-11-14 18:37:33,277 - INFO - Signal detected: Price=$48991.43, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:33,294 - INFO - Signal detected: Price=$49334.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,351 - INFO - Signal detected: Price=$49383.14, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,357 - INFO - Signal detected: Price=$48941.63, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,376 - INFO - Signal detected: Price=$48653.35, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,413 - INFO - Backtest progress: 4100/49000 bars (8.4%)
# 2025-11-14 18:37:33,424 - INFO - Signal detected: Price=$48896.27, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,440 - INFO - Signal detected: Price=$49135.40, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,460 - INFO - Signal detected: Price=$48784.78, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:33,481 - INFO - Signal detected: Price=$49120.65, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,514 - INFO - Signal detected: Price=$49101.70, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,556 - INFO - Signal detected: Price=$48620.92, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,561 - INFO - Signal detected: Price=$47930.38, BullishSweep=False, BearishSweep=False, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:37:33,564 - INFO - Backtest progress: 4200/49000 bars (8.6%)
# 2025-11-14 18:37:33,677 - INFO - Signal detected: Price=$47633.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,701 - INFO - Signal detected: Price=$48500.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,719 - INFO - Signal detected: Price=$48550.13, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,722 - INFO - Signal detected: Price=$48707.56, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,728 - INFO - Backtest progress: 4300/49000 bars (8.8%)
# 2025-11-14 18:37:33,757 - INFO - Signal detected: Price=$48638.50, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,760 - INFO - Signal detected: Price=$48647.84, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,781 - INFO - Signal detected: Price=$48682.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,809 - INFO - Signal detected: Price=$49119.38, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,812 - INFO - Signal detected: Price=$49110.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,843 - INFO - Signal detected: Price=$49826.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,852 - INFO - Signal detected: Price=$49795.17, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,854 - INFO - Signal detected: Price=$49772.14, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,878 - INFO - Backtest progress: 4400/49000 bars (9.0%)
# 2025-11-14 18:37:33,902 - INFO - Signal detected: Price=$51438.34, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,933 - INFO - Signal detected: Price=$51683.45, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,946 - INFO - Signal detected: Price=$52274.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,961 - INFO - Signal detected: Price=$51576.81, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,965 - INFO - Signal detected: Price=$51310.01, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:33,987 - INFO - Signal detected: Price=$50895.79, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,008 - INFO - Signal detected: Price=$51187.95, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,030 - INFO - Backtest progress: 4500/49000 bars (9.2%)
# 2025-11-14 18:37:34,073 - INFO - Signal detected: Price=$50981.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,131 - INFO - Signal detected: Price=$50785.78, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,191 - INFO - Backtest progress: 4600/49000 bars (9.4%)
# 2025-11-14 18:37:34,196 - INFO - Signal detected: Price=$51514.12, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,230 - INFO - Signal detected: Price=$49779.60, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,328 - INFO - Signal detected: Price=$49069.95, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,331 - INFO - Signal detected: Price=$48883.43, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,335 - INFO - Signal detected: Price=$49070.27, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,343 - INFO - Backtest progress: 4700/49000 bars (9.6%)
# 2025-11-14 18:37:34,363 - INFO - Signal detected: Price=$49285.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,379 - INFO - Signal detected: Price=$49456.46, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,452 - INFO - Signal detected: Price=$49923.72, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,485 - INFO - Backtest progress: 4800/49000 bars (9.8%)
# 2025-11-14 18:37:34,502 - INFO - Signal detected: Price=$48200.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,508 - INFO - Signal detected: Price=$47945.61, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,514 - INFO - Signal detected: Price=$48015.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,528 - INFO - Signal detected: Price=$48008.22, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,549 - INFO - Signal detected: Price=$48151.62, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,558 - INFO - Signal detected: Price=$48162.43, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,573 - INFO - Signal detected: Price=$48459.20, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,634 - INFO - Backtest progress: 4900/49000 bars (10.0%)
# 2025-11-14 18:37:34,723 - INFO - Signal detected: Price=$47109.54, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,788 - INFO - Signal detected: Price=$51881.06, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:34,789 - INFO - Backtest progress: 5000/49000 bars (10.2%)
# 2025-11-14 18:37:34,814 - INFO - Signal detected: Price=$52308.29, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,839 - INFO - Signal detected: Price=$51783.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,870 - INFO - Signal detected: Price=$52375.36, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,934 - INFO - Backtest progress: 5100/49000 bars (10.4%)
# 2025-11-14 18:37:34,971 - INFO - Signal detected: Price=$53247.57, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:34,998 - INFO - Signal detected: Price=$52879.14, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,000 - INFO - Signal detected: Price=$52938.67, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,009 - INFO - Signal detected: Price=$53022.33, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,038 - INFO - Signal detected: Price=$53228.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,070 - INFO - Signal detected: Price=$53290.85, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,076 - INFO - Signal detected: Price=$53430.85, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,087 - INFO - Backtest progress: 5200/49000 bars (10.6%)
# 2025-11-14 18:37:35,115 - INFO - Signal detected: Price=$53797.67, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,131 - INFO - Signal detected: Price=$53710.66, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,134 - INFO - Signal detected: Price=$53707.60, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,171 - INFO - Signal detected: Price=$54144.76, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,260 - INFO - Backtest progress: 5300/49000 bars (10.8%)
# 2025-11-14 18:37:35,266 - INFO - Signal detected: Price=$54800.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,276 - INFO - Signal detected: Price=$54643.73, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,288 - INFO - Signal detected: Price=$54681.45, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,393 - INFO - Signal detected: Price=$54926.87, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,416 - INFO - Signal detected: Price=$54898.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,422 - INFO - Backtest progress: 5400/49000 bars (11.0%)
# 2025-11-14 18:37:35,489 - INFO - Signal detected: Price=$54290.90, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,506 - INFO - Signal detected: Price=$54595.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,532 - INFO - Signal detected: Price=$55024.13, BullishSweep=False, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:37:35,575 - INFO - Backtest progress: 5500/49000 bars (11.2%)
# 2025-11-14 18:37:35,596 - INFO - Signal detected: Price=$55855.64, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,600 - INFO - Signal detected: Price=$55729.55, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,644 - INFO - Signal detected: Price=$55807.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,672 - INFO - Signal detected: Price=$56184.62, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,675 - INFO - Signal detected: Price=$56281.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,712 - INFO - Signal detected: Price=$55912.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,728 - INFO - Backtest progress: 5600/49000 bars (11.4%)
# 2025-11-14 18:37:35,778 - INFO - Signal detected: Price=$56298.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,781 - INFO - Signal detected: Price=$56217.23, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,788 - INFO - Signal detected: Price=$56151.44, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,793 - INFO - Signal detected: Price=$56303.15, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,846 - INFO - Signal detected: Price=$56131.08, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,877 - INFO - Backtest progress: 5700/49000 bars (11.6%)
# 2025-11-14 18:37:35,882 - INFO - Signal detected: Price=$55951.59, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,890 - INFO - Signal detected: Price=$55966.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,908 - INFO - Signal detected: Price=$55922.88, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,911 - INFO - Signal detected: Price=$55666.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:37:35,922 - INFO - Signal detected: Price=$55574.93, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# ...
# 2025-11-14 18:38:40,762 - INFO - Signal detected: Price=$16723.82, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,776 - INFO - Signal detected: Price=$16726.58, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,780 - INFO - Signal detected: Price=$16714.06, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,787 - INFO - Backtest progress: 47400/49000 bars (96.7%)
# 2025-11-14 18:38:40,803 - INFO - Signal detected: Price=$16703.01, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,852 - INFO - Signal detected: Price=$16685.84, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,865 - INFO - Signal detected: Price=$16687.07, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,867 - INFO - Signal detected: Price=$16665.26, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,878 - INFO - Signal detected: Price=$16689.08, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,944 - INFO - Signal detected: Price=$16688.90, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:40,955 - INFO - Backtest progress: 47500/49000 bars (96.9%)
# 2025-11-14 18:38:40,997 - INFO - Signal detected: Price=$16695.99, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,007 - INFO - Signal detected: Price=$16701.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,028 - INFO - Signal detected: Price=$16718.04, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,039 - INFO - Signal detected: Price=$16714.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,105 - INFO - Backtest progress: 47600/49000 bars (97.1%)
# 2025-11-14 18:38:41,108 - INFO - Signal detected: Price=$16724.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,139 - INFO - Signal detected: Price=$16742.37, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,152 - INFO - Signal detected: Price=$16766.56, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,168 - INFO - Signal detected: Price=$16758.32, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,172 - INFO - Signal detected: Price=$16744.52, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,180 - INFO - Signal detected: Price=$16740.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,211 - INFO - Signal detected: Price=$16746.68, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,247 - INFO - Signal detected: Price=$16713.65, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,258 - INFO - Signal detected: Price=$16701.84, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,261 - INFO - Backtest progress: 47700/49000 bars (97.3%)
# 2025-11-14 18:38:41,277 - INFO - Signal detected: Price=$16704.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,293 - INFO - Signal detected: Price=$16707.88, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,334 - INFO - Signal detected: Price=$16691.50, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,414 - INFO - Signal detected: Price=$16762.40, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,420 - INFO - Backtest progress: 47800/49000 bars (97.6%)
# 2025-11-14 18:38:41,436 - INFO - Signal detected: Price=$16743.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,535 - INFO - Signal detected: Price=$16784.18, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,547 - INFO - Signal detected: Price=$16792.78, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,561 - INFO - Signal detected: Price=$16786.65, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,565 - INFO - Signal detected: Price=$16765.70, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,580 - INFO - Backtest progress: 47900/49000 bars (97.8%)
# 2025-11-14 18:38:41,591 - INFO - Signal detected: Price=$16671.92, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,596 - INFO - Signal detected: Price=$16680.12, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,628 - INFO - Signal detected: Price=$16710.16, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,632 - INFO - Signal detected: Price=$16720.07, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,670 - INFO - Signal detected: Price=$16721.56, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,693 - INFO - Signal detected: Price=$16751.03, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,701 - INFO - Signal detected: Price=$16748.05, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,730 - INFO - Signal detected: Price=$16828.37, BullishSweep=True, BearishSweep=False, BullishFVG=True, BearishFVG=False
# 2025-11-14 18:38:41,731 - INFO - Maximum daily trades reached: 3/3
# 2025-11-14 18:38:41,732 - INFO - Backtest progress: 48000/49000 bars (98.0%)
# 2025-11-14 18:38:41,755 - INFO - Signal detected: Price=$16844.10, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,779 - INFO - Signal detected: Price=$16829.19, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,795 - INFO - Signal detected: Price=$16846.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,799 - INFO - Signal detected: Price=$16857.90, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,841 - INFO - Signal detected: Price=$16832.52, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,845 - INFO - Signal detected: Price=$16826.49, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,855 - INFO - Signal detected: Price=$16803.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,891 - INFO - Backtest progress: 48100/49000 bars (98.2%)
# 2025-11-14 18:38:41,898 - INFO - Signal detected: Price=$16826.64, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,902 - INFO - Signal detected: Price=$16838.07, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,913 - INFO - Signal detected: Price=$16837.55, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,923 - INFO - Signal detected: Price=$16858.84, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,927 - INFO - Signal detected: Price=$16836.58, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,946 - INFO - Signal detected: Price=$16821.28, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:41,949 - INFO - Signal detected: Price=$16820.37, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,024 - INFO - Signal detected: Price=$16695.80, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,053 - INFO - Backtest progress: 48200/49000 bars (98.4%)
# 2025-11-14 18:38:42,066 - INFO - Signal detected: Price=$16637.59, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,162 - INFO - Signal detected: Price=$16802.96, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,186 - INFO - Signal detected: Price=$16824.06, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,211 - INFO - Backtest progress: 48300/49000 bars (98.6%)
# 2025-11-14 18:38:42,297 - INFO - Signal detected: Price=$16838.24, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,351 - INFO - Signal detected: Price=$16828.71, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,375 - INFO - Backtest progress: 48400/49000 bars (98.8%)
# 2025-11-14 18:38:42,391 - INFO - Signal detected: Price=$16851.70, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,424 - INFO - Signal detected: Price=$16842.64, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,439 - INFO - Signal detected: Price=$16855.66, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,456 - INFO - Signal detected: Price=$16884.61, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,529 - INFO - Backtest progress: 48500/49000 bars (99.0%)
# 2025-11-14 18:38:42,538 - INFO - Signal detected: Price=$16834.26, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,646 - INFO - Signal detected: Price=$16779.33, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,680 - INFO - Signal detected: Price=$16813.38, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,682 - INFO - Signal detected: Price=$16807.92, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,690 - INFO - Signal detected: Price=$16810.89, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,692 - INFO - Signal detected: Price=$16806.46, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,693 - INFO - Backtest progress: 48600/49000 bars (99.2%)
# 2025-11-14 18:38:42,703 - INFO - Signal detected: Price=$16815.58, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,745 - INFO - Signal detected: Price=$16833.30, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,749 - INFO - Signal detected: Price=$16823.00, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,808 - INFO - Signal detected: Price=$16842.36, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,839 - INFO - Signal detected: Price=$16832.17, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,847 - INFO - Backtest progress: 48700/49000 bars (99.4%)
# 2025-11-14 18:38:42,867 - INFO - Signal detected: Price=$16833.43, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,872 - INFO - Signal detected: Price=$16830.01, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,956 - INFO - Signal detected: Price=$16832.48, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:42,992 - INFO - Signal detected: Price=$16839.11, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,008 - INFO - Backtest progress: 48800/49000 bars (99.6%)
# 2025-11-14 18:38:43,039 - INFO - Signal detected: Price=$16841.25, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,049 - INFO - Signal detected: Price=$16842.97, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,076 - INFO - Signal detected: Price=$16820.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,110 - INFO - Signal detected: Price=$16838.00, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,133 - INFO - Signal detected: Price=$16841.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=True
# 2025-11-14 18:38:43,134 - INFO - Maximum daily trades reached: 3/3
# 2025-11-14 18:38:43,160 - INFO - Backtest progress: 48900/49000 bars (99.8%)
# 2025-11-14 18:38:43,197 - INFO - Signal detected: Price=$16818.47, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,224 - INFO - Signal detected: Price=$16825.05, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,250 - INFO - Signal detected: Price=$16826.39, BullishSweep=True, BearishSweep=False, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,299 - INFO - Signal detected: Price=$16823.44, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,302 - INFO - Signal detected: Price=$16822.78, BullishSweep=False, BearishSweep=True, BullishFVG=False, BearishFVG=False
# 2025-11-14 18:38:43,315 - INFO -
# ============================================================
# 2025-11-14 18:38:43,316 - INFO - BACKTEST RESULTS
# 2025-11-14 18:38:43,317 - INFO - ============================================================
# 2025-11-14 18:38:43,318 - INFO - Total Trades: 3
# 2025-11-14 18:38:43,319 - INFO - Winning Trades: 1
# 2025-11-14 18:38:43,319 - INFO - Losing Trades: 2
# 2025-11-14 18:38:43,320 - INFO - Win Rate: 33.33%
# 2025-11-14 18:38:43,321 - INFO -
# Performance Metrics:
# 2025-11-14 18:38:43,322 - INFO - Total Return: -71.50%
# 2025-11-14 18:38:43,323 - INFO - ROI: -71.50%
# 2025-11-14 18:38:43,324 - INFO - Initial Capital: $10,000.00
# 2025-11-14 18:38:43,324 - INFO - Final Equity: $2,849.64
# 2025-11-14 18:38:43,325 - INFO - Net Profit: $-7,150.36
# 2025-11-14 18:38:43,326 - INFO -
# Risk Metrics:
# 2025-11-14 18:38:43,327 - INFO - Sharpe Ratio: -11.9788
# 2025-11-14 18:38:43,327 - INFO - Max Drawdown: -73.53%
# 2025-11-14 18:38:43,328 - INFO - Profit Factor: 0.0276
# 2025-11-14 18:38:43,329 - INFO - Average Win: 2.03%
# 2025-11-14 18:38:43,330 - INFO - Average Loss: -36.77%
# 2025-11-14 18:38:43,331 - INFO - ============================================================
#
# 2025-11-14 18:38:43,403 - ERROR - Error inserting backtest results: relation "backtest_results" does not exist
# LINE 2:                 INSERT INTO backtest_results (
#                                     ^
# Traceback (most recent call last):
#   File "/tmp/ipykernel_15775/813405135.py", line 237, in insert_backtest_results
#     cur.execute("""
# psycopg2.errors.UndefinedTable: relation "backtest_results" does not exist
# LINE 2:                 INSERT INTO backtest_results (
#                                     ^
#
# 🏃 View run smiling-skunk-493 at: http://mlflow:5000/#/experiments/1/runs/c3ec26b240be441bb7c9a2d3588a7583
# 🧪 View experiment at: http://mlflow:5000/#/experiments/1
#
# ============================================================
# BACKTEST SUMMARY
# ============================================================
# Total Trades: 3
# Long Trades: 3
# Short Trades: 0
#
# Sharpe Ratio: -11.9788
# Total Return: -71.50%
# ROI: -71.50%
# Max Drawdown: -73.53%
# Profit Factor: 0.0276
# Win Rate: 33.33%
# ============================================================

# %%
conn = config.db.pool.getconn()
cur = conn.cursor()
cur.execute("SELECT DISTINCT symbol, COUNT(*) as count FROM ohlcv_data GROUP BY symbol;")
for row in cur.fetchall():
    print(f"Symbol: {row[0]}, Count: {row[1]}")
config.db.pool.putconn(conn)
# Out:
# Symbol: BTC/USD, Count: 73000
