# %%
# In your Jupyter notebook, run this cell
from prometheus_client import start_http_server
import time

# Start metrics server on port 8000
start_http_server(8000)

# Keep kernel alive
while True:
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 6
#       3 import time
#       5 # Start metrics server on port 8000
# ----> 6 start_http_server(8000)
#       8 # Keep kernel alive
#       9 while True:
#
# File /opt/conda/lib/python3.11/site-packages/prometheus_client/exposition.py:241, in start_wsgi_server(port, addr, registry, certfile, keyfile, client_cafile, client_capath, protocol, client_auth_required)
#     239 TmpServer.address_family, addr = _get_best_family(addr, port)
#     240 app = make_wsgi_app(registry)
# --> 241 httpd = make_server(addr, port, app, TmpServer, handler_class=_SilentHandler)
#     242 if certfile and keyfile:
#     243     context = _get_ssl_ctx(certfile, keyfile, protocol, client_cafile, client_capath, client_auth_required)
#
# File /opt/conda/lib/python3.11/wsgiref/simple_server.py:154, in make_server(host, port, app, server_class, handler_class)
#     150 def make_server(
#     151     host, port, app, server_class=WSGIServer, handler_class=WSGIRequestHandler
#     152 ):
#     153     """Create a new WSGI server listening on `host` and `port` for `app`"""
# --> 154     server = server_class((host, port), handler_class)
#     155     server.set_app(app)
#     156     return server
#
# File /opt/conda/lib/python3.11/socketserver.py:456, in TCPServer.__init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     454 if bind_and_activate:
#     455     try:
# --> 456         self.server_bind()
#     457         self.server_activate()
#     458     except:
#
# File /opt/conda/lib/python3.11/wsgiref/simple_server.py:50, in WSGIServer.server_bind(self)
#      48 def server_bind(self):
#      49     """Override server_bind to store the server name."""
# ---> 50     HTTPServer.server_bind(self)
#      51     self.setup_environ()
#
# File /opt/conda/lib/python3.11/http/server.py:136, in HTTPServer.server_bind(self)
#     134 def server_bind(self):
#     135     """Override server_bind to store the server name."""
# --> 136     socketserver.TCPServer.server_bind(self)
#     137     host, port = self.server_address[:2]
#     138     self.server_name = socket.getfqdn(host)
#
# File /opt/conda/lib/python3.11/socketserver.py:472, in TCPServer.server_bind(self)
#     470 if self.allow_reuse_port and hasattr(socket, "SO_REUSEPORT"):
#     471     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 472 self.socket.bind(self.server_address)
#     473 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 98] Address already in use
